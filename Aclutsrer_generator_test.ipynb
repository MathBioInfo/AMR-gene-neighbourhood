# %%
import pandas as pd
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import pdist
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import average,complete,single,weighted,centroid
import plotly.figure_factory as ff
import scipy.spatial as scs
from scipy.spatial.distance import pdist,squareform
from numpy import savetxt
from matplotlib.ticker import AutoMinorLocator
from matplotlib import gridspec
import plotly.figure_factory as ff
import scipy.cluster.hierarchy as sch
import matplotlib
import seaborn as sns; sns.set()
from scipy.cluster.hierarchy import dendrogram, fcluster, leaves_list,linkage
from scipy.spatial import distance
from scipy.cluster import hierarchy# You can use SciPy one too
import os
import sys
import warnings
import glob
from Bio import SeqIO
import itertools
import numpy as np
import time

# %%
startTime = time.time()
# Collect the path for .rgi files from user and load
path = '/home/amjad/NICHEnbhd/allrgisrequired/'
readfiles=glob.glob(os.path.join(path,"*.txt"))

# %%
# Collect the path for .gbk files from user and load
path = '/home/amjad/NICHEnbhd/allgbksrequired/'
gbkfiles=glob.glob(os.path.join(path,"*.gbk"))

# %%
# Function to extract the required data from gbk files(entire genomes:) using biopython library #  
def extract(infile):
  gene_start=[]
  gene_end=[]
  gene_strand=[]
  gene_name=[]
  loc_tag=[]
  function=[]
  protein_seq=[]
  contig_name=[]
  unique=[]

  for index, record in enumerate(SeqIO.parse(infile, "genbank")):
    #print("index %i, ID = %s, length %i, with %i features"% (index, record.id, len(record.seq), len(record.features)))
    for i in record.features:
        if i.type == "CDS" and "gene" in i.qualifiers:
          locations=i.location
          gene_start.append(locations.start)
          gene_end.append(locations.end)
          gene_strand.append(locations.strand)
          loc_tag.append(i.qualifiers['locus_tag'])
          function.append(i.qualifiers['product'])
          protein_seq.append(str(i.qualifiers['translation']))
          gene_name.append(i.qualifiers['gene'])
          contig_name.append(record.id)
        elif i.type =="CDS":
          locations=i.location
          gene_start.append(locations.start)
          gene_end.append(locations.end)
          gene_strand.append(locations.strand)
          loc_tag.append(i.qualifiers['locus_tag'])
          function.append(i.qualifiers['product'])
          protein_seq.append(str(i.qualifiers['translation']))
          gene_name.append("UID")
          contig_name.append(record.id)
          
  salmonella_gene_frame=pd.DataFrame()
  salmonella_gene_frame['GeneStart']=gene_start
  salmonella_gene_frame['GeneEnd']=gene_end
  salmonella_gene_frame['GeneStrand']=gene_strand
  salmonella_gene_frame['Locus_Tag']=loc_tag
  salmonella_gene_frame['GeneName']=gene_name
  salmonella_gene_frame['Product']=function
  salmonella_gene_frame['ProteinSequence']=protein_seq
  salmonella_gene_frame['contig_name']=contig_name
  
  #print(contig_name)
  for i in contig_name:
    if i not in unique:
      unique.append(i)


  return salmonella_gene_frame,unique

# %%
# Function to create groups based on contigs #
def make_groups(frame,column):
  group=frame.groupby(frame[column])
  datasets = {}  
  for groups, data in group:
    datasets[groups] = data
  return datasets

# %%
#Creating separate dictionary for all the unique AMR genes of the genome as "key" using the field "Best_Hit_ARO" #
def createeachdict_drug(drugindex):
	temp_dict={}
	for j,k in datadict.items():       
	    temp=k[k['Best_Hit_ARO']==drugindex]
	    if len(temp)>0:
	        temp_dict[j]=temp
	return temp_dict

# %%
# A function to assign color to all and any AMR genes in the neighborhood based on CARD color codes for strict, loose and perfect hits #
color_Dict={"Loose":"#DC7633 ","Perfect":"#28B463","Strict":"#F4D03F"}
def checkforRGIinneighborhood(e,genome,rgi_gene):
    for q in range(len(e["GeneEnd"])):
        for p in range(len(datadict[genome]["Stop"])):
            datadict[genome].reset_index(drop=True, inplace=True)
            #print(e["GeneEnd"][q],p)
            if e["GeneEnd"][q] == datadict[genome]["Stop"][p] and e["GeneName"][q]==rgi_gene:
                e["Genecolor"][q]=color_Dict[datadict[genome]["Cut_Off"][p]]
                                    
    return e

# %%
# A function to delete keys of those AMR genes who are not present in atleast 25% of the total genomes ##
def delete_keys_lessthan_25percent_instances(dict_element):
    total_genomes= len(gbkfiles)
    minimum_genomes = int((total_genomes /25)*100)
    emptykeyslist=[]
    for i,j in dict_element.items():
        if len(j)<=minimum_genomes:
            emptykeyslist.append(i)
    for i in emptykeyslist:
        del dict_element[i]
    return dict_element

# %%
# A function to compute neighbors of each AMR gene based on contig info ##
def find_neighbor(rec,uname,data,number_of_genes,drug,genome,key,instancetype):
      
      neighbor_genes=[]
      rec.reset_index(drop=True, inplace=True)
      contig_flag=0

      for j in range(len(rec['Start'])):
            m=[]
            n=[]
            upwardgenes=[]
            downwardgenes=[]
            recarray=[]
            i=rec.loc[j].Start
            w=rec.loc[j].Stop
            k=rec.loc[j].req_cont
            g=number_of_genes


            if k in uname:
                newlist=data[k]
                newlist.reset_index(drop=True, inplace=True)
                for l in range(len(newlist)):
                    if newlist['GeneStart'][l] > i and newlist['GeneEnd'][l] > w:
                        downwardgenes.append((newlist['GeneStart'][l],newlist['GeneEnd'][l],newlist['GeneStrand'][l],newlist['Locus_Tag'][l],newlist['ProteinSequence'][l],newlist['GeneName'][l],"#A9F1EE","Not_Applicable"))
                    else:
                        upwardgenes.append((newlist['GeneStart'][l],newlist['GeneEnd'][l],newlist['GeneStrand'][l],newlist['Locus_Tag'][l],newlist['ProteinSequence'][l],newlist['GeneName'][l],"#A9F1EE","Not_Applicable"))
                    #print(upwardgenes) 

                newu=pd.DataFrame(upwardgenes,columns=["GeneStart","GeneEnd","Strand","Locus_Tag","ProteinSequence","GeneName","Genecolor","Gene_Cut_Off"])
                m=(newu.iloc[(newu['GeneStart']-i).abs().argsort()[:g+1]]).sort_values(by="GeneStart")
                #print(m)
                newd=pd.DataFrame(downwardgenes,columns=["GeneStart","GeneEnd","Strand","Locus_Tag","ProteinSequence","GeneName","Genecolor","Gene_Cut_Off"])
                n=(newd.iloc[(newd['GeneStart']-i).abs().argsort()[:g]]).sort_values(by="GeneStart")
                #print(n)


                recarray.append((rec['Start'][j],rec['Stop'][j],rec['Orientation'][j],rec['Locus_Tag'][j],rec['Predicted_Protein'][j],rec['Best_Hit_ARO'][j],"#ccccff",rec["Cut_Off"][j]))
                o=pd.DataFrame(recarray,columns=["GeneStart","GeneEnd","Strand","Locus_Tag","ProteinSequence","GeneName","Genecolor","Gene_Cut_Off"])


            else:
                print(k,genome)
                print("contig does not exist----"+"drugclass:"+drug)
                print(rec['Best_Hit_ARO'][j])
      
      
      if len(m)!=0 and len(n)==0:
          m.reset_index(drop=True, inplace=True)
          m=m.drop([len(m)-1])
          e = pd.concat([m,o,n], ignore_index=True)
          e.reset_index(drop=True, inplace=True)
          neighbor_genes.append(e)
              
      if len(m)==0 and len(n)!=0:

          m.reset_index(drop=True, inplace=True)
          n=n.drop([len(n)-1])
          e = pd.concat([m,o,n], ignore_index=True)
          e.reset_index(drop=True, inplace=True)
          neighbor_genes.append(e)
         

      if(len(m)!=0 and len(n)!=0):
        m.reset_index(drop=True, inplace=True)
        m=m.drop([len(m)-1])
        e = pd.concat([m,o,n], ignore_index=True)
        e.reset_index(drop=True, inplace=True)
        neighbor_genes.append(e)
            
      return neighbor_genes,contig_flag

# %%
# A function to get separate dicts of locus tags,protein sequences and gene names inorder to compare and write to a fasta file####
def getrequiredgenes(frame,number_of_genes,drug):
    temp_locus_array=[]
    temp_protein_array=[]
    temp_genename=[]
    #print(drug)
    for i in frame:
        temp_locus_array.append(list(i['Locus_Tag']))
        temp_protein_array.append(i['ProteinSequence'])
        temp_genename.append((i['GeneName']))
    
    
    locus_to_protein_dict={}
    for i in frame:
        for j in range(len(i)):
            
            locus_to_protein_dict[i['Locus_Tag'][j].strip()]=i['ProteinSequence'][j]
  
    a=temp_locus_array
    a=list(itertools.chain.from_iterable(a))
   
    b=temp_protein_array
    b=list(itertools.chain.from_iterable(b))
   
    c=temp_genename
    c=list(itertools.chain.from_iterable(c))
    
 
    if number_of_genes==10:
        if len(frame)>1:
            return(a[:10]+a[-10:], b[:10]+b[-10:],c[:10]+c[-10:])## for more than one card genes in a genomes
        else:
            return a,b,c
        #return(a[:5]+a[-5:], b[:5]+b[-5:],c[:5]+c[-5:])## for more than one card genes in a genomes
    if number_of_genes==14:
        
        if len(frame)>1:
            print(drug)
            return(a[:14]+a[-14:], b[:14]+b[-14:],c[:14]+c[-14:])## for more than one card genes in a genomes
        else:
            return a,b,c

# %%
# A function to manipulate contig to compare whether the RGI and GBK genes belong to same contig#####

def locus_generator(frame,genome_name):
    tag=[]
    RGI_name_array=[]
        
    frame.reset_index(drop=True, inplace=True)
    for index in range(len(frame)):
        temp_name=frame["Best_Hit_ARO"][index].split(" ")
        if len(temp_name)>1:
            name=(temp_name[0][0]+temp_name[1][0]+"_"+temp_name[2])
            RGI_name_array.append(name)
        else:
            name=(temp_name[0])
            RGI_name_array.append(name)
            
        tag.append(genome_name+"("+name+")"+frame["Cut_Off"][index][0]+"_"+str(frame["Best_Identities"][index]))
        
    return tag,RGI_name_array

# %%
# Read each rgi file(.txt) using pandas and store them in a dataframe#
dataframelist=[]
filenames=[]
datadict={}

# %%
for i in sorted(readfiles): 
    dfak=pd.read_csv(i,sep="\t") # added by ak to replace '/' by '-'
    dfak["Best_Hit_ARO"] = dfak["Best_Hit_ARO"].apply(lambda x: x.replace("/", "-"))
    filenames.append(os.path.basename(i).split(".")[0])
    dataframelist.append(pd.DataFrame(dfak))

# %%
# Dictionary of dataframes with keys as filenames ###
for i in range(len(filenames)):
    datadict[filenames[i]]=pd.DataFrame(dataframelist[i])

# %%
# Replacing the orientation of rgi dataframe to match the data in .gbk format to help with comparison #
for i,j in datadict.items():
    j["Orientation"]=j["Orientation"].replace("-","-1")
    j["Orientation"]=j["Orientation"].replace("+","+1")

# %%
# Adding two new columns 1> Modified Locus tag and 2> contig to extract the right neighbors #
for k,v in datadict.items():
    newcon=[]
    for i in v["Contig"]:
        head,sep,tail=i.partition("_")
        newcon.append(head)
    v['req_cont']=newcon    #adding a new column "req_cont" into dataframe
    v['Locus_Tag'],v["Best_Hit_ARO"]=locus_generator(v,k)

# %%
# Read the .gnk file data, store the info in the sorted order in dictionaries #
gbk_names=[]
uniquenames=[]
datasetslist=[]
gbkdict={}
uniquedict={}

# %%
for i in sorted(gbkfiles):    
    gbk_names.append(os.path.basename(i).split(".")[0])

# %%
for i in gbk_names:
    uniquenames.append(str(i))
    datasetslist.append(str(i))

# %%
gbkfiles=sorted(gbkfiles) #read the files in the sorted order

for i in range(len(gbk_names)):
    a=gbk_names[i]
    b=uniquenames[i]
    gbkdict[a],uniquedict[b]=extract(gbkfiles[i])

# %%
# Convert the Locus tag column from  ['SA200015_0001'] --> SA200015_001 to help while writing to fasta file required to BLAST #
for j,i in gbkdict.items():
    i['Locus_Tag']=i['Locus_Tag'].apply(lambda i:str(i).replace("[","").replace("]","").replace("'",""))
    i['ProteinSequence']=i['ProteinSequence'].str.strip('[]')

# %%
# To supress the warning that arise when a single value of dataframe column is manipulated #
def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()

# %%
pd.set_option('mode.chained_assignment', None)
# The block that causes the chained assignment error #

for i,j in gbkdict.items():
    for value in range(len(j["GeneName"])):
        if isinstance(j["GeneName"].iloc[value], list):
            j["GeneName"].iloc[value] = j["GeneName"].iloc[value][0]

# %%
# For each .gbk file, divides the data based on available contigs using groupby and dictionary, used to find the neighbors of same contig# 
datasetdict={}
for i in range(len(gbk_names)):
    for j,k in gbkdict.items():
        datasetdict[j]=make_groups(k,"contig_name")

# %%
# Finds the union of all the AMR genes present in more than 25 percent of the total genomes #
uniquedrugdict={}
unionofdrugclasess=[]

for j,k in datadict.items():
    uniquedrugclasses=[]
    for l in range(len(k)):
        if k['Best_Hit_ARO'][l]  not in uniquedrugclasses:
                uniquedrugclasses.append(k["Best_Hit_ARO"][l])
    uniquedrugdict[j]=uniquedrugclasses
        
for i,j in uniquedrugdict.items():
    for item in j:
        if item not in unionofdrugclasess:
            unionofdrugclasess.append(item)

# %%
# Converts the longer AMR gene names into shorter version to make them as dictionary keys and to make it easier to visualize in gene order image#
# Haemophilis influenzea PBP3 --> Hi_PBP3#

listofdrugnames_modified=[]
for k in unionofdrugclasess:
    if len(k.split(" "))>1:
        temp=k.split(" ")
        listofdrugnames_modified.append(temp[0][0]+temp[1][0]+"_"+temp[2])
    else:

        listofdrugnames_modified.append(k.split("; ")[0].split(" ")[0])

# %%
# A main dictionary of all the AMR models with all the genomes 
main_dictionary={}
for i in range(len(listofdrugnames_modified)):
    main_dictionary[listofdrugnames_modified[i]]=createeachdict_drug(unionofdrugclasess[i])
#main_dictionary=delete_keys_lessthan_25percent_instances(main_dictionary)

# %%
# Divide the AMR genes into single instance and multiple instance #            
Dict_multigene_instances={}
Dict_singlegene_instances={}
for i,j in main_dictionary.items():
    temp={}
    flag=0
    for a,b in j.items():
        
        if len(b)>1:
            flag=1
    if flag==1:
        Dict_multigene_instances[i]=j
    else:
        Dict_singlegene_instances[i]=j

# %%
# Code to get one to one genome comparisons when there are multiple instances and divide the frames based on locus tags  #
dict_rgi_multiple_occurance={}
g={}
for i,j in Dict_multigene_instances.items():
    temp={}
    l=[]
    deletekeylist=[]
    for a,b in j.items():
        if len(b)>1 or len(b)==1:
            l.append(a)
            b.reset_index(drop=True, inplace=True)            
            x=make_groups(b,"Locus_Tag")
            for e,f in x.items():
                temp[e]=f

    dict_rgi_multiple_occurance[i]=temp
    g[i]=l
 
for i,j in Dict_multigene_instances.items():
    for t in g[i]:
        del j[t]
        
for i,j in dict_rgi_multiple_occurance.items():    
     j.update(Dict_multigene_instances[i])


dict_rgi_single_occurance={}
g={}
for i,j in Dict_singlegene_instances.items():
    temp={}
    l=[]
    deletekeylist=[]
    for a,b in j.items():
        if len(b)==1:
            l.append(a)
            b.reset_index(drop=True, inplace=True)            
            x=make_groups(b,"Locus_Tag")
            for e,f in x.items():
                temp[e]=f

    dict_rgi_single_occurance[i]=temp
    g[i]=l
 
for i,j in Dict_singlegene_instances.items():
    for t in g[i]:
        del j[t]
        
for i,j in dict_rgi_single_occurance.items():    
     j.update(Dict_singlegene_instances[i])

# %%
# Create separate single instance multiple instance folders
# Find the neighbors and store them in separate dictionaries

singleinstance_neighboringdict_combined_range10={}
Single_contig_end_flag_dict={}
for i,j in dict_rgi_single_occurance.items():
    Dict_neighboring_genes_range10={}
    temp_contig_flag={}
    for k,l in j.items():
        key=k.split("(")[0]
        temp,contigflag=find_neighbor(j[k],uniquedict[key],datasetdict[key],10,i,k,key,"Single_Instance_Neighborhood")
        if len(temp)>0:
            Dict_neighboring_genes_range10[k]=temp
            temp_contig_flag[k]=contigflag
    singleinstance_neighboringdict_combined_range10[i]=Dict_neighboring_genes_range10
    Single_contig_end_flag_dict[i]=temp_contig_flag
# Out:
# 133 ERR375423(vanRA)S_100.0
# contig does not exist----drugclass:vanRA
# vanRA
# 169 SRR14010935(vanRA)S_100.0
# contig does not exist----drugclass:vanRA
# vanRA
# 177 SRR14011025(vanRA)S_100.0
# contig does not exist----drugclass:vanRA
# vanRA
# 159 ERR369976(dfrF)S_100.0
# contig does not exist----drugclass:dfrF
# dfrF
# 146 ERR374958(dfrF)S_100.0
# contig does not exist----drugclass:dfrF
# dfrF
# 150 ERR375118(dfrF)S_100.0
# contig does not exist----drugclass:dfrF
# dfrF
# 151 ERR375134(dfrF)S_100.0
# contig does not exist----drugclass:dfrF
# dfrF
# 169 ERR375445(dfrF)S_100.0
# contig does not exist----drugclass:dfrF
# dfrF
# 215 ERR375471(dfrF)S_100.0
# contig does not exist----drugclass:dfrF
# dfrF
# 67 ERR1100603(poxtA)S_100.0
# contig does not exist----drugclass:poxtA
# poxtA
# 38 ERR1156191(poxtA)S_100.0
# contig does not exist----drugclass:poxtA
# poxtA
# 68 ERR1156217(poxtA)S_100.0
# contig does not exist----drugclass:poxtA
# poxtA
# 67 ERR1156236(poxtA)S_100.0
# contig does not exist----drugclass:poxtA
# poxtA
# 79 ERR987638(poxtA)S_100.0
# contig does not exist----drugclass:poxtA
# poxtA
# 66 SRR14024972(poxtA)S_100.0
# contig does not exist----drugclass:poxtA
# poxtA
# 65 SRR14024978(poxtA)S_100.0
# contig does not exist----drugclass:poxtA
# poxtA
# 58 SRR14024983(poxtA)S_100.0
# contig does not exist----drugclass:poxtA
# poxtA
# 97 SRR14024984(poxtA)S_100.0
# contig does not exist----drugclass:poxtA
# poxtA
# 71 SRR14024990(poxtA)S_100.0
# contig does not exist----drugclass:poxtA
# poxtA
# 117 SRR14025000(poxtA)S_100.0
# contig does not exist----drugclass:poxtA
# poxtA
# 52 SRR14026459(poxtA)S_100.0
# contig does not exist----drugclass:poxtA
# poxtA
# 46 SRR14026470(poxtA)S_100.0
# contig does not exist----drugclass:poxtA
# poxtA
# 59 SRR14026532(poxtA)S_100.0
# contig does not exist----drugclass:poxtA
# poxtA
# 210 ERR1100577(MexB)S_100.0
# contig does not exist----drugclass:MexB
# MexB
# 226 ERR1100631(MexB)S_100.0
# contig does not exist----drugclass:MexB
# MexB
# 391 ERR374849(AAC(6')-Iak)S_100.0
# contig does not exist----drugclass:AAC(6')-Iak
# AAC(6')-Iak
# 275 ERR375553(AAC(6')-Iak)S_100.0
# contig does not exist----drugclass:AAC(6')-Iak
# AAC(6')-Iak
# 309 ERR984997(AAC(6')-Iak)S_100.0
# contig does not exist----drugclass:AAC(6')-Iak
# AAC(6')-Iak
# 247 ERR987597(AAC(6')-Iak)S_100.0
# contig does not exist----drugclass:AAC(6')-Iak
# AAC(6')-Iak
# 391 ERR375154(LpeA)S_100.0
# contig does not exist----drugclass:LpeA
# LpeA
# 385 ERR375164(LpeA)S_100.0
# contig does not exist----drugclass:LpeA
# LpeA
# 427 ERR375156(NDM-10)S_100.0
# contig does not exist----drugclass:NDM-10
# NDM-10
# 326 ERR375427(OXA-835)S_100.0
# contig does not exist----drugclass:OXA-835
# OXA-835
# 303 ERR375476(AAC(6')-Il)S_100.0
# contig does not exist----drugclass:AAC(6')-Il
# AAC(6')-Il
# 314 ERR375585(EreA2)S_100.0
# contig does not exist----drugclass:EreA2
# EreA2

# %%
multipleinstance_neighboringdict_combined_range_10={}
multiple_contig_end_flag_dict={}
for i,j in dict_rgi_multiple_occurance.items():
    Dict_neighboring_genes_range10={}
    temp_contig_flag={}
    for k,l in j.items():
        key=k.split("(")[0]
        temp,contigflag=find_neighbor(j[k],uniquedict[key],datasetdict[key],10,i,k,key,"Multiple_Instance_Neighborhood")
        if len(temp)>0:
            Dict_neighboring_genes_range10[key]=temp
            temp_contig_flag[key]=contigflag
    multipleinstance_neighboringdict_combined_range_10[i]=Dict_neighboring_genes_range10
    multiple_contig_end_flag_dict[i]=temp_contig_flag
# Out:
# 164 ERR985045(Td_reductase)S_41.03
# contig does not exist----drugclass:Td_reductase
# Td_reductase
# 139 ERR985080(Td_reductase)S_41.03
# contig does not exist----drugclass:Td_reductase
# Td_reductase
# 142 SRR14010935(Td_reductase)S_41.03
# contig does not exist----drugclass:Td_reductase
# Td_reductase
# 175 SRR14010938(Td_reductase)S_41.03
# contig does not exist----drugclass:Td_reductase
# Td_reductase
# 180 SRR14010943(Td_reductase)S_41.03
# contig does not exist----drugclass:Td_reductase
# Td_reductase
# 166 SRR14010945(Td_reductase)S_41.03
# contig does not exist----drugclass:Td_reductase
# Td_reductase
# 160 SRR14010946(Td_reductase)S_41.03
# contig does not exist----drugclass:Td_reductase
# Td_reductase
# 141 SRR14010960(Td_reductase)S_41.03
# contig does not exist----drugclass:Td_reductase
# Td_reductase
# 148 SRR14010969(Td_reductase)S_41.03
# contig does not exist----drugclass:Td_reductase
# Td_reductase
# 153 SRR14010970(Td_reductase)S_41.03
# contig does not exist----drugclass:Td_reductase
# Td_reductase
# 166 SRR14010985(Td_reductase)S_41.03
# contig does not exist----drugclass:Td_reductase
# Td_reductase
# 153 SRR14010993(Td_reductase)S_41.03
# contig does not exist----drugclass:Td_reductase
# Td_reductase
# 152 SRR14011002(Td_reductase)S_41.03
# contig does not exist----drugclass:Td_reductase
# Td_reductase
# 156 SRR14011006(Td_reductase)S_41.03
# contig does not exist----drugclass:Td_reductase
# Td_reductase
# 150 SRR14011025(Td_reductase)S_41.03
# contig does not exist----drugclass:Td_reductase
# Td_reductase
# 142 SRR14011032(Td_reductase)S_41.03
# contig does not exist----drugclass:Td_reductase
# Td_reductase
# 187 ERR1036028(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 191 ERR1036028(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 179 ERR1036028(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 103 ERR1036044(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 127 ERR1036044(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 112 ERR1036044(tetM)S_96.94
# contig does not exist----drugclass:tetM
# tetM
# 111 ERR1036057(tetM)S_96.94
# contig does not exist----drugclass:tetM
# tetM
# 185 ERR1036059(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 174 ERR1036060(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 227 ERR1036070(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 224 ERR1069046(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 172 ERR1069046(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 102 ERR1100588(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 120 ERR1100588(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 137 ERR1100588(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 88 ERR1100588(tetM)S_97.03
# contig does not exist----drugclass:tetM
# tetM
# 90 ERR1100594(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 102 ERR1100594(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 128 ERR1100594(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 80 ERR1100594(tetM)S_97.03
# contig does not exist----drugclass:tetM
# tetM
# 76 ERR1100596(tetM)S_96.94
# contig does not exist----drugclass:tetM
# tetM
# 131 ERR1100598(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 114 ERR1100599(tetM)S_98.52
# contig does not exist----drugclass:tetM
# tetM
# 158 ERR1100625(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 185 ERR1100625(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 160 ERR1100632(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 161 ERR1100632(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 174 ERR1100633(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 207 ERR1100633(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 157 ERR1100633(tetM)S_98.28
# contig does not exist----drugclass:tetM
# tetM
# 73 ERR1156197(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 86 ERR1156197(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 76 ERR1156197(tetM)S_96.94
# contig does not exist----drugclass:tetM
# tetM
# 154 ERR1156206(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 108 ERR1156207(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 109 ERR1156222(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 119 ERR1156223(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 88 ERR1156231(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 107 ERR1156231(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 99 ERR1156231(tetM)S_96.94
# contig does not exist----drugclass:tetM
# tetM
# 131 ERR1156254(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 154 ERR1156254(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 157 ERR1156254(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 97 ERR1156258(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 92 ERR1156264(tetM)S_96.51
# contig does not exist----drugclass:tetM
# tetM
# 104 ERR1156268(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 96 ERR1156268(tetM)S_96.51
# contig does not exist----drugclass:tetM
# tetM
# 93 ERR1156320(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 86 ERR1156320(tetM)S_96.51
# contig does not exist----drugclass:tetM
# tetM
# 150 ERR1216304(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 154 ERR1216304(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 144 ERR1216304(tetM)S_97.82
# contig does not exist----drugclass:tetM
# tetM
# 201 ERR369941(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 183 ERR369941(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 241 ERR369951(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 207 ERR369951(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 38 ERR369955(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 46 ERR369955(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 39 ERR369955(tetM)S_96.94
# contig does not exist----drugclass:tetM
# tetM
# 230 ERR369958(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 310 ERR369958(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 200 ERR369958(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 175 ERR369964(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 157 ERR369964(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 215 ERR369969(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 184 ERR369969(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 187 ERR369972(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 196 ERR369972(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 155 ERR369976(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 143 ERR369976(tetM)S_97.38
# contig does not exist----drugclass:tetM
# tetM
# 186 ERR369978(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 174 ERR369978(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 194 ERR369980(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 172 ERR369980(tetM)S_97.38
# contig does not exist----drugclass:tetM
# tetM
# 242 ERR369992(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 207 ERR369992(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 192 ERR369996(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 177 ERR369996(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 215 ERR369997(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 193 ERR369997(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 166 ERR369998(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 152 ERR369998(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 167 ERR370003(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 195 ERR370003(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 185 ERR370005(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 265 ERR370007(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 379 ERR370007(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 228 ERR370007(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 176 ERR370015(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 164 ERR370015(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 194 ERR370019(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 183 ERR370019(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 237 ERR370021(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 209 ERR370021(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 179 ERR370023(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 187 ERR370023(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 210 ERR370029(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 214 ERR370029(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 188 ERR370029(tetM)S_98.57
# contig does not exist----drugclass:tetM
# tetM
# 171 ERR370030(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 161 ERR370030(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 183 ERR374662(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 169 ERR374662(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 261 ERR374674(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 231 ERR374674(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 225 ERR374675(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 191 ERR374675(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 246 ERR374679(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 215 ERR374679(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 195 ERR374683(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 174 ERR374683(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 233 ERR374686(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 203 ERR374686(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 212 ERR374697(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 189 ERR374697(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 225 ERR374701(tetM)S_97.6
# contig does not exist----drugclass:tetM
# tetM
# 199 ERR374701(tetM)S_98.57
# contig does not exist----drugclass:tetM
# tetM
# 262 ERR374707(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 286 ERR374707(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 215 ERR374721(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 193 ERR374721(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 172 ERR374724(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 158 ERR374724(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 229 ERR374743(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 195 ERR374743(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 181 ERR374744(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 231 ERR374744(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 183 ERR374746(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 175 ERR374746(tetM)S_97.38
# contig does not exist----drugclass:tetM
# tetM
# 190 ERR374753(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 171 ERR374753(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 243 ERR374754(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 212 ERR374754(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 203 ERR374769(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 184 ERR374769(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 225 ERR374804(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 198 ERR374804(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 215 ERR374811(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 193 ERR374811(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 204 ERR374813(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 184 ERR374813(tetM)S_97.38
# contig does not exist----drugclass:tetM
# tetM
# 226 ERR374826(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 197 ERR374826(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 181 ERR374829(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 170 ERR374829(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 195 ERR374843(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 259 ERR374843(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 169 ERR374843(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 247 ERR374848(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 218 ERR374848(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 283 ERR374849(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 221 ERR374849(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 240 ERR374855(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 354 ERR374855(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 204 ERR374855(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 235 ERR374856(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 209 ERR374856(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 244 ERR374864(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 211 ERR374864(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 184 ERR374871(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 169 ERR374871(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 211 ERR374882(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 189 ERR374882(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 175 ERR374883(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 157 ERR374883(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 204 ERR374894(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 187 ERR374894(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 196 ERR374907(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 172 ERR374907(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 167 ERR374912(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 154 ERR374912(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 217 ERR374913(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 305 ERR374913(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 184 ERR374913(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 220 ERR374914(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 199 ERR374914(tetM)S_97.38
# contig does not exist----drugclass:tetM
# tetM
# 197 ERR374919(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 175 ERR374919(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 184 ERR374924(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 228 ERR374924(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 165 ERR374924(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 172 ERR374929(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 158 ERR374929(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 243 ERR374930(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 210 ERR374930(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 218 ERR374938(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 194 ERR374938(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 235 ERR374939(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 210 ERR374939(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 206 ERR374944(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 184 ERR374944(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 263 ERR374949(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 219 ERR374949(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 213 ERR374965(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 186 ERR374965(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 182 ERR374971(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 171 ERR374971(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 174 ERR374992(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 162 ERR374992(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 267 ERR374993(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 226 ERR374993(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 228 ERR374998(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 306 ERR374998(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 209 ERR375010(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 189 ERR375010(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 204 ERR375013(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 227 ERR375013(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 205 ERR375015(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 257 ERR375015(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 185 ERR375015(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 267 ERR375018(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 228 ERR375018(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 246 ERR375019(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 354 ERR375019(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 209 ERR375019(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 226 ERR375022(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 205 ERR375022(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 251 ERR375023(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 218 ERR375023(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 287 ERR375027(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 297 ERR375027(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 218 ERR375027(tetM)S_98.57
# contig does not exist----drugclass:tetM
# tetM
# 196 ERR375028(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 183 ERR375028(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 181 ERR375030(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 221 ERR375030(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 164 ERR375030(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 191 ERR375031(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 171 ERR375031(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 239 ERR375035(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 204 ERR375035(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 245 ERR375057(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 204 ERR375057(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 200 ERR375062(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 179 ERR375062(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 262 ERR375071(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 221 ERR375071(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 227 ERR375075(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 313 ERR375075(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 197 ERR375075(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 212 ERR375079(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 191 ERR375079(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 221 ERR375083(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 189 ERR375083(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 175 ERR375091(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 161 ERR375091(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 186 ERR375094(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 236 ERR375094(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 161 ERR375094(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 248 ERR375105(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 216 ERR375105(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 251 ERR375109(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 274 ERR375109(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 182 ERR375114(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 168 ERR375114(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 177 ERR375130(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 160 ERR375130(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 194 ERR375135(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 176 ERR375135(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 260 ERR375138(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 222 ERR375138(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 206 ERR375143(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 189 ERR375143(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 235 ERR375153(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 337 ERR375153(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 205 ERR375153(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 172 ERR375157(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 221 ERR375157(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 238 ERR375161(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 208 ERR375161(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 203 ERR375174(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 181 ERR375174(tetM)S_97.38
# contig does not exist----drugclass:tetM
# tetM
# 194 ERR375188(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 182 ERR375188(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 193 ERR375195(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 176 ERR375195(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 219 ERR375226(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 192 ERR375226(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 247 ERR375246(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 219 ERR375246(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 245 ERR375248(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 210 ERR375248(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 205 ERR375257(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 186 ERR375257(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 263 ERR375311(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 239 ERR375311(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 215 ERR375313(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 193 ERR375313(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 220 ERR375318(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 195 ERR375318(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 234 ERR375330(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 202 ERR375330(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 250 ERR375333(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 216 ERR375333(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 321 ERR375334(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 210 ERR375334(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 249 ERR375334(tetM)S_99.19
# contig does not exist----drugclass:tetM
# tetM
# 176 ERR375335(tetM)S_98.42
# contig does not exist----drugclass:tetM
# tetM
# 184 ERR375335(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 173 ERR375347(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 223 ERR375360(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 232 ERR375360(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 190 ERR375360(tetM)S_98.57
# contig does not exist----drugclass:tetM
# tetM
# 222 ERR375365(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 198 ERR375365(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 231 ERR375382(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 281 ERR375382(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 208 ERR375382(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 179 ERR375409(tetM)S_98.42
# contig does not exist----drugclass:tetM
# tetM
# 193 ERR375409(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 270 ERR375427(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 279 ERR375427(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 233 ERR375427(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 234 ERR375430(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 205 ERR375430(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 230 ERR375434(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 205 ERR375434(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 234 ERR375436(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 201 ERR375436(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 165 ERR375445(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 154 ERR375445(tetM)S_97.38
# contig does not exist----drugclass:tetM
# tetM
# 211 ERR375452(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 187 ERR375452(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 207 ERR375471(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 179 ERR375471(tetM)S_97.38
# contig does not exist----drugclass:tetM
# tetM
# 188 ERR375480(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 174 ERR375480(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 191 ERR375481(tetM)S_98.42
# contig does not exist----drugclass:tetM
# tetM
# 205 ERR375481(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 244 ERR375483(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 213 ERR375483(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 258 ERR375494(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 230 ERR375494(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 244 ERR375496(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 208 ERR375496(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 189 ERR375497(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 167 ERR375497(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 256 ERR375498(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 229 ERR375498(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 253 ERR375506(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 222 ERR375506(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 232 ERR375512(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 202 ERR375512(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 229 ERR375529(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 202 ERR375529(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 224 ERR375544(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 233 ERR375544(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 194 ERR375544(tetM)S_98.57
# contig does not exist----drugclass:tetM
# tetM
# 223 ERR375553(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 195 ERR375553(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 181 ERR375556(tetM)S_98.42
# contig does not exist----drugclass:tetM
# tetM
# 195 ERR375556(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 229 ERR377425(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 205 ERR377425(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 186 ERR377430(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 177 ERR377430(tetM)S_97.38
# contig does not exist----drugclass:tetM
# tetM
# 177 ERR377437(tetM)S_98.42
# contig does not exist----drugclass:tetM
# tetM
# 186 ERR377437(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 230 ERR377438(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 222 ERR377444(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 192 ERR377444(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 191 ERR377450(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 185 ERR377458(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 195 ERR377458(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 223 ERR377465(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 229 ERR377465(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 189 ERR377465(tetM)S_98.57
# contig does not exist----drugclass:tetM
# tetM
# 176 ERR377469(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 181 ERR377469(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 164 ERR377469(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 211 ERR377474(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 214 ERR377474(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 186 ERR377474(tetM)S_98.57
# contig does not exist----drugclass:tetM
# tetM
# 214 ERR377483(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 189 ERR377483(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 179 ERR377484(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 172 ERR377485(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 161 ERR377485(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 189 ERR377501(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 248 ERR388689(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 215 ERR388689(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 201 ERR388691(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 259 ERR388691(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 245 ERR388692(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 216 ERR388692(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 206 ERR388693(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 182 ERR388693(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 237 ERR388701(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 250 ERR388701(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 212 ERR388701(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 252 ERR388715(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 226 ERR388715(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 261 ERR388717(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 269 ERR388717(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 212 ERR388717(tetM)S_98.57
# contig does not exist----drugclass:tetM
# tetM
# 204 ERR388718(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 185 ERR388718(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 198 ERR388725(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 185 ERR388725(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 138 ERR984977(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 175 ERR984984(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 163 ERR984984(tetM)S_97.38
# contig does not exist----drugclass:tetM
# tetM
# 200 ERR984985(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 151 ERR984986(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 183 ERR984987(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 184 ERR984990(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 173 ERR984990(tetM)S_97.38
# contig does not exist----drugclass:tetM
# tetM
# 221 ERR984997(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 132 ERR985015(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 170 ERR985022(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 159 ERR985023(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 193 ERR985034(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 249 ERR985039(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 221 ERR985043(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 221 ERR985045(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 208 ERR985047(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 189 ERR985064(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 187 ERR985068(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 162 ERR985069(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 177 ERR985069(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 190 ERR985069(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 173 ERR985069(tetM)S_96.03
# contig does not exist----drugclass:tetM
# tetM
# 191 ERR985074(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 180 ERR985074(tetM)S_97.38
# contig does not exist----drugclass:tetM
# tetM
# 181 ERR985080(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 161 ERR985082(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 168 ERR985082(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 177 ERR985082(tetM)S_95.54
# contig does not exist----drugclass:tetM
# tetM
# 231 ERR985083(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 161 ERR985085(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 182 ERR985089(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 194 ERR985089(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 209 ERR985102(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 188 ERR985113(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 200 ERR985117(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 177 ERR985120(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 218 ERR985123(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 188 ERR985128(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 216 ERR985130(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 198 ERR985133(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 187 ERR985133(tetM)S_97.38
# contig does not exist----drugclass:tetM
# tetM
# 198 ERR987508(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 203 ERR987511(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 172 ERR987514(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 196 ERR987515(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 184 ERR987516(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 188 ERR987516(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 172 ERR987516(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 189 ERR987519(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 195 ERR987526(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 195 ERR987527(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 196 ERR987540(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 181 ERR987543(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 176 ERR987547(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 187 ERR987551(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 118 ERR987562(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 198 ERR987585(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 172 ERR987590(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 176 ERR987590(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 190 ERR987590(tetM)S_95.54
# contig does not exist----drugclass:tetM
# tetM
# 216 ERR987592(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 185 ERR987593(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 187 ERR987593(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 171 ERR987593(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 199 ERR987597(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 146 ERR987601(tetM)S_98.46
# contig does not exist----drugclass:tetM
# tetM
# 172 ERR987602(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 211 ERR987605(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 207 ERR987615(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 200 ERR987617(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 194 ERR987626(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 198 ERR987639(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 158 ERR987651(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 206 SRR14010935(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 208 SRR14010942(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 204 SRR14011001(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 206 SRR14011025(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 48 SRR14024961(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 60 SRR14024961(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 52 SRR14024961(tetM)S_96.94
# contig does not exist----drugclass:tetM
# tetM
# 88 SRR14024972(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 83 SRR14024972(tetM)S_96.51
# contig does not exist----drugclass:tetM
# tetM
# 81 SRR14024978(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 77 SRR14024978(tetM)S_96.51
# contig does not exist----drugclass:tetM
# tetM
# 52 SRR14024980(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 53 SRR14024980(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 167 SRR14026516(tetM)S_98.57
# contig does not exist----drugclass:tetM
# tetM
# 107 SRR14026542(tetM)S_100.0
# contig does not exist----drugclass:tetM
# tetM
# 156 SRR14026551(tetM)S_98.47
# contig does not exist----drugclass:tetM
# tetM
# 133 ERR375423(vanSA)S_100.0
# contig does not exist----drugclass:vanSA
# vanSA
# 157 ERR987590(vanSA)S_100.0
# contig does not exist----drugclass:vanSA
# vanSA
# 221 ERR369954(vanYA)S_100.0
# contig does not exist----drugclass:vanYA
# vanYA
# 206 ERR369969(vanYA)S_100.0
# contig does not exist----drugclass:vanYA
# vanYA
# 206 ERR369982(vanYA)S_100.0
# contig does not exist----drugclass:vanYA
# vanYA
# 175 ERR370021(vanYA)S_100.0
# contig does not exist----drugclass:vanYA
# vanYA
# 185 ERR374701(vanYA)S_100.0
# contig does not exist----drugclass:vanYA
# vanYA
# 196 ERR374893(vanYA)S_100.0
# contig does not exist----drugclass:vanYA
# vanYA
# 182 ERR375019(vanYA)S_100.0
# contig does not exist----drugclass:vanYA
# vanYA
# 164 ERR375313(vanYA)S_100.0
# contig does not exist----drugclass:vanYA
# vanYA
# 147 ERR375413(vanYA)S_100.0
# contig does not exist----drugclass:vanYA
# vanYA
# 165 ERR375423(vanYA)S_100.0
# contig does not exist----drugclass:vanYA
# vanYA
# 172 ERR375430(vanYA)S_100.0
# contig does not exist----drugclass:vanYA
# vanYA
# 160 ERR375452(vanYA)S_100.0
# contig does not exist----drugclass:vanYA
# vanYA
# 155 ERR377473(vanYA)S_100.0
# contig does not exist----drugclass:vanYA
# vanYA
# 157 ERR388718(vanYA)S_100.0
# contig does not exist----drugclass:vanYA
# vanYA
# 193 ERR1100565(ANT(6)-Ia)S_100.0
# contig does not exist----drugclass:ANT(6)-Ia
# ANT(6)-Ia
# 176 ERR1100565(ANT(6)-Ia)S_99.23
# contig does not exist----drugclass:ANT(6)-Ia
# ANT(6)-Ia
# 179 ERR1100577(ANT(6)-Ia)S_100.0
# contig does not exist----drugclass:ANT(6)-Ia
# ANT(6)-Ia
# 118 ERR1100601(ANT(6)-Ia)S_100.0
# contig does not exist----drugclass:ANT(6)-Ia
# ANT(6)-Ia
# 120 ERR1100601(ANT(6)-Ia)S_100.0
# contig does not exist----drugclass:ANT(6)-Ia
# ANT(6)-Ia
# 114 ERR1100602(ANT(6)-Ia)S_100.0
# contig does not exist----drugclass:ANT(6)-Ia
# ANT(6)-Ia
# 202 ERR1100630(ANT(6)-Ia)S_100.0
# contig does not exist----drugclass:ANT(6)-Ia
# ANT(6)-Ia
# 192 ERR1100631(ANT(6)-Ia)S_100.0
# contig does not exist----drugclass:ANT(6)-Ia
# ANT(6)-Ia
# 50 ERR1156186(ANT(6)-Ia)S_100.0
# contig does not exist----drugclass:ANT(6)-Ia
# ANT(6)-Ia
# 98 ERR1156230(ANT(6)-Ia)S_100.0
# contig does not exist----drugclass:ANT(6)-Ia
# ANT(6)-Ia
# 106 ERR1156252(ANT(6)-Ia)S_100.0
# contig does not exist----drugclass:ANT(6)-Ia
# ANT(6)-Ia
# 91 ERR1156267(ANT(6)-Ia)S_100.0
# contig does not exist----drugclass:ANT(6)-Ia
# ANT(6)-Ia
# 86 ERR1156269(ANT(6)-Ia)S_100.0
# contig does not exist----drugclass:ANT(6)-Ia
# ANT(6)-Ia
# 89 ERR1156269(ANT(6)-Ia)S_100.0
# contig does not exist----drugclass:ANT(6)-Ia
# ANT(6)-Ia
# 175 ERR1156290(ANT(6)-Ia)S_100.0
# contig does not exist----drugclass:ANT(6)-Ia
# ANT(6)-Ia
# 183 ERR1156290(ANT(6)-Ia)S_100.0
# contig does not exist----drugclass:ANT(6)-Ia
# ANT(6)-Ia
# 169 ERR1156293(ANT(6)-Ia)S_100.0
# contig does not exist----drugclass:ANT(6)-Ia
# ANT(6)-Ia
# 176 ERR1156293(ANT(6)-Ia)S_100.0
# contig does not exist----drugclass:ANT(6)-Ia
# ANT(6)-Ia
# 196 ERR369998(ANT(6)-Ia)S_100.0
# contig does not exist----drugclass:ANT(6)-Ia
# ANT(6)-Ia
# 294 ERR374693(ANT(6)-Ia)S_100.0
# contig does not exist----drugclass:ANT(6)-Ia
# ANT(6)-Ia
# 273 ERR374957(ANT(6)-Ia)S_100.0
# contig does not exist----drugclass:ANT(6)-Ia
# ANT(6)-Ia
# 203 ERR388702(ANT(6)-Ia)S_100.0
# contig does not exist----drugclass:ANT(6)-Ia
# ANT(6)-Ia
# 173 ERR985127(ANT(6)-Ia)S_100.0
# contig does not exist----drugclass:ANT(6)-Ia
# ANT(6)-Ia
# 133 ERR1036065(ErmB)S_98.29
# contig does not exist----drugclass:ErmB
# ErmB
# 157 ERR1100572(ErmB)S_98.67
# contig does not exist----drugclass:ErmB
# ErmB
# 65 ERR1156203(ErmB)S_100.0
# contig does not exist----drugclass:ErmB
# ErmB
# 56 ERR1156203(ErmB)S_98.68
# contig does not exist----drugclass:ErmB
# ErmB
# 138 ERR1156206(ErmB)S_99.11
# contig does not exist----drugclass:ErmB
# ErmB
# 104 ERR1156233(ErmB)S_98.67
# contig does not exist----drugclass:ErmB
# ErmB
# 104 ERR1156248(ErmB)S_98.67
# contig does not exist----drugclass:ErmB
# ErmB
# 72 ERR1156253(ErmB)S_100.0
# contig does not exist----drugclass:ErmB
# ErmB
# 192 ERR375281(ErmB)S_97.39
# contig does not exist----drugclass:ErmB
# ErmB
# 179 ERR375406(ErmB)S_98.25
# contig does not exist----drugclass:ErmB
# ErmB
# 182 ERR375476(ErmB)S_98.25
# contig does not exist----drugclass:ErmB
# ErmB
# 167 ERR388702(ErmB)S_98.25
# contig does not exist----drugclass:ErmB
# ErmB
# 172 ERR985073(ErmB)S_98.25
# contig does not exist----drugclass:ErmB
# ErmB
# 170 ERR985075(ErmB)S_98.25
# contig does not exist----drugclass:ErmB
# ErmB
# 181 ERR985076(ErmB)S_98.25
# contig does not exist----drugclass:ErmB
# ErmB
# 132 ERR985127(ErmB)S_98.67
# contig does not exist----drugclass:ErmB
# ErmB
# 154 ERR987590(ErmB)S_98.25
# contig does not exist----drugclass:ErmB
# ErmB
# 97 SRR14022735(ErmB)S_98.46
# contig does not exist----drugclass:ErmB
# ErmB
# 108 SRR14022735(ErmB)S_99.13
# contig does not exist----drugclass:ErmB
# ErmB
# 71 SRR14022762(ErmB)S_98.46
# contig does not exist----drugclass:ErmB
# ErmB
# 154 ERR1036028(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 203 ERR1036028(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 147 ERR1036058(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 168 ERR1036058(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 186 ERR1036059(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 198 ERR1036059(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 215 ERR1036059(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 229 ERR1036059(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 133 ERR1036061(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 157 ERR1036061(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 91 ERR1100601(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 144 ERR369966(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 233 ERR369966(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 150 ERR369981(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 243 ERR369981(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 178 ERR369993(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 227 ERR369993(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 263 ERR370000(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 179 ERR370011(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 236 ERR370011(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 145 ERR370018(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 122 ERR370033(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 151 ERR374663(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 234 ERR374663(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 119 ERR374685(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 192 ERR374693(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 270 ERR374693(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 119 ERR374723(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 159 ERR374727(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 161 ERR374735(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 211 ERR374735(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 123 ERR374752(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 159 ERR374760(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 255 ERR374760(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 190 ERR374770(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 243 ERR374770(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 249 ERR374770(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 131 ERR374774(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 174 ERR374774(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 168 ERR374793(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 295 ERR374793(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 170 ERR374806(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 209 ERR374806(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 116 ERR374824(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 157 ERR374824(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 139 ERR374828(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 240 ERR374828(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 134 ERR374835(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 165 ERR374899(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 245 ERR374899(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 150 ERR374909(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 237 ERR374909(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# ...
# AAC(6')-Ie-APH(2'')-Ia
# 120 ERR375160(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 195 ERR375164(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 367 ERR375164(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 155 ERR375287(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 188 ERR375287(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 168 ERR375353(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 297 ERR375353(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 146 ERR375361(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 157 ERR375361(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 135 ERR375392(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 172 ERR375446(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 304 ERR375446(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 159 ERR375448(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 182 ERR375448(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 139 ERR375450(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 172 ERR375450(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 144 ERR375466(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 221 ERR375466(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 170 ERR375522(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 220 ERR375522(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 168 ERR375538(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 205 ERR375538(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 180 ERR375544(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 246 ERR375544(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 267 ERR375544(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 270 ERR375544(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 170 ERR377433(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 229 ERR377433(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 126 ERR377446(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 128 ERR377481(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 162 ERR377497(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 141 ERR388688(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 183 ERR388688(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 160 ERR388701(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 219 ERR388701(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 145 ERR388724(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 162 ERR984978(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 225 ERR984978(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 136 ERR985001(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 163 ERR985001(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 142 ERR985015(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 148 ERR985015(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 179 ERR985015(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 182 ERR985022(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 191 ERR985022(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 245 ERR985022(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 168 ERR985023(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 179 ERR985023(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 222 ERR985023(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 167 ERR985026(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 190 ERR985026(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 166 ERR985035(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 189 ERR985035(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 179 ERR985039(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 234 ERR985039(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 210 ERR985047(AAC(6')-Ie-APH(2'')-Ia)S_99.48
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 180 ERR985081(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 184 ERR985081(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 218 ERR985081(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 172 ERR985085(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 184 ERR985085(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 226 ERR985085(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 196 ERR985094(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 205 ERR985094(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 263 ERR985094(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 143 ERR985109(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 174 ERR985109(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 146 ERR985111(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 174 ERR985111(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 154 ERR985120(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 234 ERR985120(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 146 ERR985121(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 177 ERR985121(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 305 ERR985130(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 140 ERR987509(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 171 ERR987509(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 184 ERR987514(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 195 ERR987514(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 231 ERR987514(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 152 ERR987516(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 175 ERR987516(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 135 ERR987541(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 156 ERR987541(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 136 ERR987544(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 161 ERR987544(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 135 ERR987553(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 195 ERR987553(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 167 ERR987617(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 253 ERR987617(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 136 ERR987627(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 140 ERR987629(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 211 ERR987640(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 217 ERR987640(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 168 ERR987651(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 178 ERR987651(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 219 ERR987651(AAC(6')-Ie-APH(2'')-Ia)S_100.0
# contig does not exist----drugclass:AAC(6')-Ie-APH(2'')-Ia
# AAC(6')-Ie-APH(2'')-Ia
# 231 ERR375023(ErmT)S_98.1
# contig does not exist----drugclass:ErmT
# ErmT
# 200 ERR375138(ErmT)S_99.02
# contig does not exist----drugclass:ErmT
# ErmT
# 79 ERR1100598(tet(W-N-W))S_61.62
# contig does not exist----drugclass:tet(W-N-W)
# tet(W-N-W)
# 121 ERR1100632(tet(W-N-W))S_66.99
# contig does not exist----drugclass:tet(W-N-W)
# tet(W-N-W)
# 102 ERR1100637(tet(W-N-W))S_67.68
# contig does not exist----drugclass:tet(W-N-W)
# tet(W-N-W)
# 76 SRR14022745(tet(W-N-W))S_66.13
# contig does not exist----drugclass:tet(W-N-W)
# tet(W-N-W)
# 77 SRR14022745(tet(W-N-W))S_66.13
# contig does not exist----drugclass:tet(W-N-W)
# tet(W-N-W)
# 163 ERR1100565(aad(6))S_100.0
# contig does not exist----drugclass:aad(6)
# aad(6)
# 169 ERR1100630(aad(6))S_100.0
# contig does not exist----drugclass:aad(6)
# aad(6)
# 183 ERR1100630(aad(6))S_100.0
# contig does not exist----drugclass:aad(6)
# aad(6)
# 71 ERR1156237(aad(6))S_100.0
# contig does not exist----drugclass:aad(6)
# aad(6)
# 170 ERR1156290(aad(6))S_100.0
# contig does not exist----drugclass:aad(6)
# aad(6)
# 164 ERR369998(aad(6))S_100.0
# contig does not exist----drugclass:aad(6)
# aad(6)
# 163 ERR1100565(SAT-4)S_98.91
# contig does not exist----drugclass:SAT-4
# SAT-4
# 169 ERR1100630(SAT-4)S_98.91
# contig does not exist----drugclass:SAT-4
# SAT-4
# 71 ERR1156237(SAT-4)S_98.68
# contig does not exist----drugclass:SAT-4
# SAT-4
# 170 ERR1156290(SAT-4)S_98.55
# contig does not exist----drugclass:SAT-4
# SAT-4
# 151 ERR374820(SAT-4)S_100.0
# contig does not exist----drugclass:SAT-4
# SAT-4
# 148 ERR374832(SAT-4)S_100.0
# contig does not exist----drugclass:SAT-4
# SAT-4
# 155 ERR374972(SAT-4)S_100.0
# contig does not exist----drugclass:SAT-4
# SAT-4
# 169 ERR375209(SAT-4)S_100.0
# contig does not exist----drugclass:SAT-4
# SAT-4
# 283 ERR375427(SAT-4)S_97.92
# contig does not exist----drugclass:SAT-4
# SAT-4
# 151 ERR374820(APH(3')-IIIa)S_100.0
# contig does not exist----drugclass:APH(3')-IIIa
# APH(3')-IIIa
# 169 ERR374820(APH(3')-IIIa)S_100.0
# contig does not exist----drugclass:APH(3')-IIIa
# APH(3')-IIIa
# 148 ERR374832(APH(3')-IIIa)S_100.0
# contig does not exist----drugclass:APH(3')-IIIa
# APH(3')-IIIa
# 169 ERR375209(APH(3')-IIIa)S_100.0
# contig does not exist----drugclass:APH(3')-IIIa
# APH(3')-IIIa
# 110 SRR14022735(APH(3')-IIIa)S_100.0
# contig does not exist----drugclass:APH(3')-IIIa
# APH(3')-IIIa
# 71 SRR14022762(APH(3')-IIIa)S_100.0
# contig does not exist----drugclass:APH(3')-IIIa
# APH(3')-IIIa
# 163 ERR1100633(tet(L))S_99.44
# contig does not exist----drugclass:tet(L)
# tet(L)
# 174 ERR374959(tet(L))S_100.0
# contig does not exist----drugclass:tet(L)
# tet(L)
# 130 ERR374732(tetU)S_95.0
# contig does not exist----drugclass:tetU
# tetU
# 128 ERR374937(tetU)S_95.0
# contig does not exist----drugclass:tetU
# tetU
# 158 ERR374979(tetU)S_95.45
# contig does not exist----drugclass:tetU
# tetU
# 169 ERR375018(tetU)S_100.0
# contig does not exist----drugclass:tetU
# tetU
# 170 ERR375071(tetU)S_96.0
# contig does not exist----drugclass:tetU
# tetU
# 139 ERR375092(tetU)S_96.0
# contig does not exist----drugclass:tetU
# tetU
# 134 ERR375161(tetU)S_96.0
# contig does not exist----drugclass:tetU
# tetU
# 142 ERR375406(tetU)S_95.65
# contig does not exist----drugclass:tetU
# tetU
# 142 ERR375476(tetU)S_95.65
# contig does not exist----drugclass:tetU
# tetU
# 158 ERR375494(tetU)S_95.65
# contig does not exist----drugclass:tetU
# tetU
# 162 ERR375498(tetU)S_95.65
# contig does not exist----drugclass:tetU
# tetU
# 147 ERR375542(tetU)S_95.65
# contig does not exist----drugclass:tetU
# tetU
# 151 ERR377468(tetU)S_95.65
# contig does not exist----drugclass:tetU
# tetU
# 145 ERR388702(tetU)S_95.65
# contig does not exist----drugclass:tetU
# tetU
# 180 ERR388723(tetU)S_95.65
# contig does not exist----drugclass:tetU
# tetU
# 136 ERR985073(tetU)S_95.65
# contig does not exist----drugclass:tetU
# tetU
# 135 ERR985075(tetU)S_95.65
# contig does not exist----drugclass:tetU
# tetU
# 141 ERR985076(tetU)S_95.65
# contig does not exist----drugclass:tetU
# tetU
# 113 ERR987544(tetU)S_98.88
# contig does not exist----drugclass:tetU
# tetU

# %%
# Code to extract the locus tags, protein sequences and gene names to use to later for comparison #
Drug_singleinstance_range_10_locus_dict10={}
Drug_singleinstance_range_10_protein_dict10={}
Drug_singleinstance_range_10_genename_dict10={}

for i,j in singleinstance_neighboringdict_combined_range10.items():
    locustags_dict_10={}
    protein_dict_10={}
    genename_dict_10={}
    for k,l in j.items():
        locustags_dict_10[k],protein_dict_10[k],genename_dict_10[k]=getrequiredgenes(j[k],10,i)  
    Drug_singleinstance_range_10_locus_dict10[i]=locustags_dict_10
    Drug_singleinstance_range_10_protein_dict10[i]=protein_dict_10
    Drug_singleinstance_range_10_genename_dict10[i]=genename_dict_10

# %%
Drug_multiple_instance_range_10_locus_dict10={}
Drug_multiple_instance_range_10_protein_dict10={}
Drug_multiple_instance_range_10_genename_dict10={}

for i,j in multipleinstance_neighboringdict_combined_range_10.items():

    locustags_dict_10={}
    protein_dict_10={}
    genename_dict_10={}
    for k,l in j.items():

        locustags_dict_10[k],protein_dict_10[k],genename_dict_10[k]=getrequiredgenes(j[k],10,i)
    #print(len(locustags_dict_10),len(protein_dict_10),len(genename_dict_10))  
    Drug_multiple_instance_range_10_locus_dict10[i]=locustags_dict_10
    Drug_multiple_instance_range_10_protein_dict10[i]=protein_dict_10
    Drug_multiple_instance_range_10_genename_dict10[i]=genename_dict_10

# %%
# Read the .txt files of BLAST results and store in a dictionary ######
filepath_single='/home/amjad/NICHEnbhd/Outputs/Single_instance/output_blast_single_instance'
Single_instance_blastdataframelist=[]
Single_instance_blastfilename=[]

# %%
readfiles=glob.glob(os.path.join(filepath_single,"*.txt"))
for i in readfiles:    
    Single_instance_blastfilename.append(os.path.basename(i).split(".")[0])
    i=pd.read_csv(i,index_col = False,sep="\t", names=['query_id','sub_id','PI','len','Evalue','bitscore','qseq','sseq'])
    Single_instance_blastdataframelist.append(i)

# %%
temp_Single_instance_blastdatadict={}### dictionary of dataframes with keys as filenames ###
for i in range(len(Single_instance_blastfilename)):
    a=Single_instance_blastdataframelist[i]
    b=Single_instance_blastfilename[i]
    temp_Single_instance_blastdatadict[b]=pd.DataFrame(a)

# %%
filepath_multiple='/home/amjad/NICHEnbhd/Outputs/Multiple_instance/output_blast_multiple_instance'
Multiple_instance_blastdataframelist=[]
Multiple_instance_blastfilename=[]

# %%
readfiles=glob.glob(os.path.join(filepath_multiple,"*.txt"))
for i in readfiles:
    Multiple_instance_blastfilename.append(os.path.basename(i).split(".")[0])
    i=pd.read_csv(i,index_col = False,sep="\t", names=['query_id','sub_id','PI','len','Evalue','bitscore','qseq','sseq'])
    #i=pd.read_csv(i,index_col = False,sep="\t")
    Multiple_instance_blastdataframelist.append(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_562237/3595403488.py in <module>
# ----> 1 readfiles=glob.glob(os.path.join(filepath_multiple,"*.txt"))
#       2 for i in readfiles:
#       3     Multiple_instance_blastfilename.append(os.path.basename(i).split(".")[0])
#       4     i=pd.read_csv(i,index_col = False,sep="\t", names=['query_id','sub_id','PI','len','Evalue','bitscore','qseq','sseq'])
#       5     #i=pd.read_csv(i,index_col = False,sep="\t")
#
# NameError: name 'glob' is not defined

# %%
temp_Multiple_instance_blastdatadict={}### dictionary of dataframes with keys as filenames ###
for i in range(len(Multiple_instance_blastfilename)):
    a=Multiple_instance_blastdataframelist[i]
    b=Multiple_instance_blastfilename[i]
    temp_Multiple_instance_blastdatadict[b]=pd.DataFrame(a)

# %%
# To sort and filter only those BLAST results with more than 70 percent identity 

Single_instance_blastdatadict={}
for i,j in temp_Single_instance_blastdatadict.items():
    j=j[j["PI"]>70]
    Single_instance_blastdatadict[i]=j

# %%
# A function to normalize the bitscore values 
def normalized_bitscore(z): 
  manval=[]
  a=z[z['query_id']==z['sub_id']]
  manval=[]
  a=z[z['query_id']==z['sub_id']]
  a.reset_index(drop=True, inplace=True)
  q={}
  for i in range(len(a)):
    q[a['query_id'][i]]=a['bitscore'][i]

  for i in range(len(z)):
      manval.append(round(float(z['bitscore'][i])/q[z['query_id'][i]],3))

  z['normalized_bitscore']=manval
  return z

# %%
Single_instance_drugclass_genomedict={}
for k,l in Drug_singleinstance_range_10_locus_dict10.items():
    u=Single_instance_blastdatadict[k]
    temp_dict={}
    for a,b in l.items():        
        temp=[]
        u.reset_index(drop=True, inplace=True)
        for index in range (len(u)):
            if  u["query_id"][index] in b:
                temp.append((u["query_id"][index],u["sub_id"][index],u["PI"][index],u["bitscore"][index]))
                    
        #frame=pd.DataFrame(temp,columns=["query_id","sub_id","PI","bitscore"])
        temp_dict[a]=pd.DataFrame(temp,columns=["query_id","sub_id","PI","bitscore"])
      
    Single_instance_drugclass_genomedict[k]=temp_dict
    

for i,j in Single_instance_drugclass_genomedict.items():
    for a,b in j.items():
        b=normalized_bitscore(b)

# %%
# A function to remove BLAST entry results for same gene comparison by taking the highest bit score 
def remove_duplicates(temp):
    df=pd.DataFrame(temp,columns=["query_id","sub_id","bitscore"])
    d = df.sort_values("bitscore", ascending=False)
    d = d.drop_duplicates(['query_id'])
    d.reset_index(drop=True, inplace=True)
    
    return d

# %%
single_similarity_array_dict={}
for k,l in Drug_singleinstance_range_10_locus_dict10.items():
    similarity_array=[]
    for genome1 in Single_instance_drugclass_genomedict[k].keys():  
        u=Single_instance_drugclass_genomedict[k][genome1]
        for genome2,b in l.items():
            temp=[]
            sum1=0
            sum2=0
            u.reset_index(drop=True, inplace=True)
            for index in range (len(u)):
                if u["sub_id"][index] in b:
                    temp.append((u["query_id"][index],u["sub_id"][index],u["normalized_bitscore"][index]))

            tempframe=remove_duplicates(temp)
            sum1=round(tempframe["bitscore"].sum(),3)
            
            if Single_contig_end_flag_dict[k][genome1] ==1:
                length_original_neighborhood=len(Drug_singleinstance_range_10_locus_dict10[k][genome1])
                difference=length_original_neighborhood-len(tempframe)
                sum2= sum1+(21-difference-len(tempframe))
                
            elif Single_contig_end_flag_dict[k][genome2]==1:
                length_original_neighborhood=len(Drug_singleinstance_range_10_locus_dict10[k][genome2])
                difference=length_original_neighborhood-len(tempframe)                                 
                
                sum2= sum1+(21-difference-len(tempframe))
            else:
                sum2=sum1
           
            similarity_array.append((genome1,genome2,round(sum2,3)))
    single_similarity_array_dict[k]=similarity_array

# %%
# A function to convert the similarity matrix to symmteric matric matrix by taking the average of scores
def converttosymmetrix(j):
    newj=[]
    
    for index1 in range(len(j)):
        
        score1=j[index1][2]
        for index2 in range(len(j)):
            if j[index2][1]==j[index1][0] and j[index2][0]==j[index1][1]:
                avg=round((j[index1][2]+j[index2][2])/2,3)
        newj.append((j[index1][0],j[index1][1],avg))
    return newj

# %%
# Use the function to convert to symmetric matrix and store the final matrix in separate dictionaries
Single_instance_matrixframe={}
for i,j in single_similarity_array_dict.items():
    new=converttosymmetrix(j)
    finalresult=pd.DataFrame(new,columns=["Query_id","Sub_id","normalized_bitscore"])
    sim_mat=pd.crosstab(index=finalresult.iloc[:,0], columns=finalresult.iloc[:,1],values=finalresult.iloc[:,2], aggfunc=lambda x: x,colnames=None)
    Y=sim_mat.values
    Single_instance_matrixframe[i]=sim_mat

# %%
# Generate a distance matrix and generate UPGMA clusters 
os.mkdir("Outputs/UPGMA_single_clusters")

# %%
save_path="Outputs/UPGMA_single_clusters"
dataarray=[]

# %%
hierarchy.set_link_color_palette(['r', 'g', 'y', 'm'])
matplotlib.rcParams['lines.linewidth'] = 5

# %%
for i,j in Single_instance_matrixframe.items(): 
    if len(j)>1:

        df = pd.DataFrame(j,columns=j.keys())
        r  = df.values
        df = df.transform(lambda x: 1 - x/r.max() )
        df = df.round(decimals=3)
        Y = df.values
        np.fill_diagonal(Y, 0)
        Y = distance.squareform(Y)
        fig = plt.figure(figsize=(15,5))
        Z = hierarchy.linkage(Y, 'average')
        dendrogram(Z, leaf_rotation=90, leaf_font_size=8, labels=j.keys())
        savename=os.path.join(save_path,i+"_.png")
        plt.ylabel("Distance between neighborhoods")
        plt.xlabel("Neighborhoods with their respective Genome IDs")
        plt.savefig(savename,bbox_inches='tight', dpi=100)
        plt.close()

# %%
# Execute if only there are multiple instance AMR gene models #

if len(temp_Multiple_instance_blastdatadict.keys())>0:

    Multiple_instance_blastdatadict={}
    for i,j in temp_Multiple_instance_blastdatadict.items():
        j=j[j["PI"]>70]
        j = j.reset_index().drop_duplicates(subset=['query_id','sub_id','bitscore'],keep='first').set_index('index')
        Multiple_instance_blastdatadict[i]=j


    # Divide the mixed BLAST results into their respective AMR gene models and genomes 
    multiple_instance_drugclass_genomedict={}
    for k,l in Drug_multiple_instance_range_10_locus_dict10.items():
        u=Multiple_instance_blastdatadict[k]
        temp_dict={} 
        for a,b in l.items():#          
            temp=[]
            u.reset_index(drop=True, inplace=True)
            for index in range (len(u)):
                if  u["query_id"][index] in b:
                    temp.append((u["query_id"][index],u["sub_id"][index],u["PI"][index],u["bitscore"][index]))
                        
            #frame=pd.DataFrame(temp,columns=["query_id","sub_id","PI","bitscore"])
            temp_dict[a]=pd.DataFrame(temp,columns=["query_id","sub_id","PI","bitscore"])
          
        multiple_instance_drugclass_genomedict[k]=temp_dict

    # using the function and normalizing 
    for i,j in multiple_instance_drugclass_genomedict.items():
        for a,b in j.items():
            b=normalized_bitscore(b)


    # For each gene model compare the genomes and generate a similarity matrix #
    multiple_similarity_array_dict={}
    for k,l in Drug_multiple_instance_range_10_locus_dict10.items():
        similarity_array=[]
        for genome1 in multiple_instance_drugclass_genomedict[k].keys():  
            u=multiple_instance_drugclass_genomedict[k][genome1]
            for genome2,b in l.items():
                temp=[]
                sum1=0
                sum2=0
                u.reset_index(drop=True, inplace=True)
                for index in range (len(u)):
                    if u["sub_id"][index] in b:
                        temp.append((u["query_id"][index],u["sub_id"][index],u["normalized_bitscore"][index]))

                tempframe=remove_duplicates(temp)
                sum1=round(tempframe["bitscore"].sum(),3)
                
                if multiple_contig_end_flag_dict[k][genome1] ==1:
                    length_original_neighborhood=len(Drug_multiple_instance_range_10_locus_dict10[k][genome1])
                    difference=length_original_neighborhood-len(tempframe)
                    sum2= sum1+(21-difference-len(tempframe))
                    
                elif multiple_contig_end_flag_dict[k][genome2]==1:
                    length_original_neighborhood=len(Drug_multiple_instance_range_10_locus_dict10[k][genome2])
                    difference=length_original_neighborhood-len(tempframe)                                 
                    
                    sum2= sum1+(21-difference-len(tempframe))
                else:
                    sum2=sum1
               
                similarity_array.append((genome1,genome2,round(sum1,3)))
        multiple_similarity_array_dict[k]=similarity_array

    multiple_instance_matrixframe={}
    for i,j in multiple_similarity_array_dict.items():
        new=converttosymmetrix(j)
        finalresult=pd.DataFrame(new,columns=["Query_id","Sub_id","normalized_bitscore"])
        sim_mat=pd.crosstab(index=finalresult.iloc[:,0], columns=finalresult.iloc[:,1],values=finalresult.iloc[:,2], aggfunc=lambda x: x,colnames=None)
        Y=sim_mat.values
        multiple_instance_matrixframe[i]=sim_mat

    os.mkdir("Outputs/UPGMA_multiple_clusters")
    save_path="Outputs/UPGMA_multiple_clusters"
    dataarray=[]
    hierarchy.set_link_color_palette(['r', 'g', 'y', 'm'])
    matplotlib.rcParams['lines.linewidth'] = 5
    for i,j in multiple_instance_matrixframe.items(): 
        if len(j)>1:

            df = pd.DataFrame(j,columns=j.keys())
            r  = df.values
            df = df.transform(lambda x: 1 - x/r.max() )
            df = df.round(decimals=3)
            Y = df.values
            np.fill_diagonal(Y, 0)
            Y = distance.squareform(Y)
            fig = plt.figure(figsize=(20,5))
            Z = hierarchy.linkage(Y, 'average')
            dendrogram(Z, leaf_rotation=90, leaf_font_size=8, labels=j.keys())
            savename=os.path.join(save_path,i+"_.png")
            plt.ylabel("Distance between neighborhoods")
            plt.xlabel("Neighborhoods with their respective Genome IDs")
            plt.savefig(savename,bbox_inches='tight', dpi=300)
            plt.close()

# %%
executionTime = (time.time() - startTime)   
print('Execution time in seconds: ' + str(executionTime))
