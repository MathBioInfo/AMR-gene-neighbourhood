# %%
import pandas as pd
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import pdist
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import average,complete,single,weighted,centroid
import plotly.figure_factory as ff
import scipy.spatial as scs
from scipy.spatial.distance import pdist,squareform
from numpy import savetxt
from matplotlib.ticker import AutoMinorLocator
from matplotlib import gridspec
import plotly.figure_factory as ff
import scipy.cluster.hierarchy as sch
import matplotlib
import seaborn as sns; sns.set()
from scipy.cluster.hierarchy import dendrogram, fcluster, leaves_list,linkage
from scipy.spatial import distance
from scipy.cluster import hierarchy# You can use SciPy one too
import os
import sys
import warnings
import glob
from Bio import SeqIO
import itertools
import numpy as np
from tqdm import tqdm
import time

# %%
# Collect the path for .rgi files from user and load
path = '/home/amjad/NICHEnbhd/allrgisrequired/'
readfiles=glob.glob(os.path.join(path,"*.txt"))

# %%
# Collect the path for .gbk files from user and load
path = '/home/amjad/NICHEnbhd/allgbksrequired/'
gbkfiles=glob.glob(os.path.join(path,"*.gbk"))

# %%
# Function to extract the required data from gbk files(entire genomes:) using biopython library #  
def extract(infile):
  gene_start=[]
  gene_end=[]
  gene_strand=[]
  gene_name=[]
  loc_tag=[]
  function=[]
  protein_seq=[]
  contig_name=[]
  unique=[]

  for index, record in enumerate(SeqIO.parse(infile, "genbank")):
    #print("index %i, ID = %s, length %i, with %i features"% (index, record.id, len(record.seq), len(record.features)))
    for i in record.features:
        if i.type == "CDS" and "gene" in i.qualifiers:
          locations=i.location
          gene_start.append(locations.start)
          gene_end.append(locations.end)
          gene_strand.append(locations.strand)
          loc_tag.append(i.qualifiers['locus_tag'])
          function.append(i.qualifiers['product'])
          protein_seq.append(str(i.qualifiers['translation']))
          gene_name.append(i.qualifiers['gene'])
          contig_name.append(record.id)
        elif i.type =="CDS":
          locations=i.location
          gene_start.append(locations.start)
          gene_end.append(locations.end)
          gene_strand.append(locations.strand)
          loc_tag.append(i.qualifiers['locus_tag'])
          function.append(i.qualifiers['product'])
          protein_seq.append(str(i.qualifiers['translation']))
          gene_name.append("UID")
          contig_name.append(record.id)
          
  salmonella_gene_frame=pd.DataFrame()
  salmonella_gene_frame['GeneStart']=gene_start
  salmonella_gene_frame['GeneEnd']=gene_end
  salmonella_gene_frame['GeneStrand']=gene_strand
  salmonella_gene_frame['Locus_Tag']=loc_tag
  salmonella_gene_frame['GeneName']=gene_name
  salmonella_gene_frame['Product']=function
  salmonella_gene_frame['ProteinSequence']=protein_seq
  salmonella_gene_frame['contig_name']=contig_name
  
  #print(contig_name)
  for i in contig_name:
    if i not in unique:
      unique.append(i)


  return salmonella_gene_frame,unique

# %%
# Function to create groups based on contigs #
def make_groups(frame,column):
  group=frame.groupby(frame[column])
  datasets = {}  
  for groups, data in group:
    datasets[groups] = data
  return datasets

# %%
#Creating separate dictionary for all the unique AMR genes of the genome as "key" using the field "Best_Hit_ARO" #
def createeachdict_drug(drugindex):
	temp_dict={}
	for j,k in datadict.items():       
	    temp=k[k['Best_Hit_ARO']==drugindex]
	    if len(temp)>0:
	        temp_dict[j]=temp
	return temp_dict

# %%
# A function to assign color to all and any AMR genes in the neighborhood based on CARD color codes for strict, loose and perfect hits #
color_Dict={"Loose":"#DC7633 ","Perfect":"#28B463","Strict":"#F4D03F"}
def checkforRGIinneighborhood(e,genome,rgi_gene):
    for q in range(len(e["GeneEnd"])):
        for p in range(len(datadict[genome]["Stop"])):
            datadict[genome].reset_index(drop=True, inplace=True)
            #print(e["GeneEnd"][q],p)
            if e["GeneEnd"][q] == datadict[genome]["Stop"][p] and e["GeneName"][q]==rgi_gene:
                e["Genecolor"][q]=color_Dict[datadict[genome]["Cut_Off"][p]]
                                    
    return e

# %%
# A function to delete keys of those AMR genes who are not present in atleast 25% of the total genomes ##
def delete_keys_lessthan_25percent_instances(dict_element):
    total_genomes= len(gbkfiles)
    minimum_genomes = int((total_genomes /25)*100)
    emptykeyslist=[]
    for i,j in dict_element.items():
        if len(j)<=minimum_genomes:
            emptykeyslist.append(i)
    for i in emptykeyslist:
        del dict_element[i]
    return dict_element

# %%
# A function to compute neighbors of each AMR gene based on contig info ##
def find_neighbor(rec,uname,data,number_of_genes,drug,genome,key,instancetype):
      
      neighbor_genes=[]
      rec.reset_index(drop=True, inplace=True)
      contig_flag=0

      for j in range(len(rec['Start'])):
            m=[]
            n=[]
            upwardgenes=[]
            downwardgenes=[]
            recarray=[]
            i=rec.loc[j].Start
            w=rec.loc[j].Stop
            k=rec.loc[j].req_cont
            g=number_of_genes


            if k in uname:
                newlist=data[k]
                newlist.reset_index(drop=True, inplace=True)
                for l in range(len(newlist)):
                    if newlist['GeneStart'][l] > i and newlist['GeneEnd'][l] > w:
                        downwardgenes.append((newlist['GeneStart'][l],newlist['GeneEnd'][l],newlist['GeneStrand'][l],newlist['Locus_Tag'][l],newlist['ProteinSequence'][l],newlist['GeneName'][l],"#A9F1EE","Not_Applicable"))
                    else:
                        upwardgenes.append((newlist['GeneStart'][l],newlist['GeneEnd'][l],newlist['GeneStrand'][l],newlist['Locus_Tag'][l],newlist['ProteinSequence'][l],newlist['GeneName'][l],"#A9F1EE","Not_Applicable"))
                    #print(upwardgenes) 

                newu=pd.DataFrame(upwardgenes,columns=["GeneStart","GeneEnd","Strand","Locus_Tag","ProteinSequence","GeneName","Genecolor","Gene_Cut_Off"])
                m=(newu.iloc[(newu['GeneStart']-i).abs().argsort()[:g+1]]).sort_values(by="GeneStart")
                #print(m)
                newd=pd.DataFrame(downwardgenes,columns=["GeneStart","GeneEnd","Strand","Locus_Tag","ProteinSequence","GeneName","Genecolor","Gene_Cut_Off"])
                n=(newd.iloc[(newd['GeneStart']-i).abs().argsort()[:g]]).sort_values(by="GeneStart")
                #print(n)


                recarray.append((rec['Start'][j],rec['Stop'][j],rec['Orientation'][j],rec['Locus_Tag'][j],rec['Predicted_Protein'][j],rec['Best_Hit_ARO'][j],"#ccccff",rec["Cut_Off"][j]))
                o=pd.DataFrame(recarray,columns=["GeneStart","GeneEnd","Strand","Locus_Tag","ProteinSequence","GeneName","Genecolor","Gene_Cut_Off"])


            else:
                print(k,genome)
                print("contig does not exist----"+"drugclass:"+drug)
                print(rec['Best_Hit_ARO'][j])
      
      
      if len(m)!=0 and len(n)==0:
          m.reset_index(drop=True, inplace=True)
          m=m.drop([len(m)-1])
          e = pd.concat([m,o,n], ignore_index=True)
          e.reset_index(drop=True, inplace=True)
          neighbor_genes.append(e)
              
      if len(m)==0 and len(n)!=0:

          m.reset_index(drop=True, inplace=True)
          n=n.drop([len(n)-1])
          e = pd.concat([m,o,n], ignore_index=True)
          e.reset_index(drop=True, inplace=True)
          neighbor_genes.append(e)
         

      if(len(m)!=0 and len(n)!=0):
        m.reset_index(drop=True, inplace=True)
        m=m.drop([len(m)-1])
        e = pd.concat([m,o,n], ignore_index=True)
        e.reset_index(drop=True, inplace=True)
        neighbor_genes.append(e)
            
      return neighbor_genes,contig_flag

# %%
def locus_generator(frame,genome_name):
    tag=[]
    RGI_name_array=[]
        
    frame.reset_index(drop=True, inplace=True)
    for index in range(len(frame)):
        temp_name=frame["Best_Hit_ARO"][index].split(" ")
        if len(temp_name)>1:
            name=(temp_name[0][0]+temp_name[1][0]+"_"+temp_name[2])
            RGI_name_array.append(name)
        else:
            name=(temp_name[0])
            RGI_name_array.append(name)
            
        tag.append(genome_name+"("+name+")"+frame["Cut_Off"][index][0]+"_"+str(frame["Best_Identities"][index]))
        
    return tag,RGI_name_array

# %%
# A function to get separate dicts of locus tags,protein sequences and gene names inorder to compare and write to a fasta file####
def getrequiredgenes(frame,number_of_genes,drug):
    temp_locus_array=[]
    temp_protein_array=[]
    temp_genename=[]
    #print(drug)
    for i in frame:
        temp_locus_array.append(list(i['Locus_Tag']))
        temp_protein_array.append(i['ProteinSequence'])
        temp_genename.append((i['GeneName']))
    
    
    locus_to_protein_dict={}
    for i in frame:
        for j in range(len(i)):
            
            locus_to_protein_dict[i['Locus_Tag'][j].strip()]=i['ProteinSequence'][j]
  
    a=temp_locus_array
    a=list(itertools.chain.from_iterable(a))
   
    b=temp_protein_array
    b=list(itertools.chain.from_iterable(b))
   
    c=temp_genename
    c=list(itertools.chain.from_iterable(c))
    
 
    if number_of_genes==10:
        if len(frame)>1:
            return(a[:10]+a[-10:], b[:10]+b[-10:],c[:10]+c[-10:])## for more than one card genes in a genomes
        else:
            return a,b,c
        #return(a[:5]+a[-5:], b[:5]+b[-5:],c[:5]+c[-5:])## for more than one card genes in a genomes
    if number_of_genes==14:
        
        if len(frame)>1:
            print(drug)
            return(a[:14]+a[-14:], b[:14]+b[-14:],c[:14]+c[-14:])## for more than one card genes in a genomes
        else:
            return a,b,c

# %%
# Read each rgi file(.txt) using pandas and store them in a dataframe#
# Read RGI files but focus only on vanA gene
dataframelist=[]
filenames=[]
datadict={}
for i in sorted(readfiles): 
    dfak=pd.read_csv(i,sep="\t") # added by ak to replace '/' by '-'
    dfak["Best_Hit_ARO"] = dfak["Best_Hit_ARO"].apply(lambda x: x.replace("/", "-"))
    #filenames.append(os.path.basename(i).split(".")[0])
    dfAK=pd.DataFrame(dfak)
    required_gene = dfAK[dfAK["Best_Hit_ARO"] == 'tet(45)']
    if required_gene.empty:
        print('DataFRame is empty')
    else:
        dataframelist.append(pd.DataFrame(required_gene))
        filenames.append(os.path.basename(i).split(".")[0])
    #break
# Out:
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty
# DataFRame is empty

# %%
# Dictionary of dataframes with keys as filenames ###
for i in tqdm(range(len(filenames))):
    datadict[filenames[i]]=pd.DataFrame(dataframelist[i])
    time.sleep(0.1)
# Out:
# 100%|█████████████████████████████████████████| 455/455 [00:46<00:00,  9.73it/s]

# %%
len(datadict)
# Out:
# 455

# %%
# Replacing the orientation of rgi dataframe to match the data in .gbk format to help with comparison #
for i,j in tqdm(datadict.items()):
    j["Orientation"]=j["Orientation"].replace("-","-1")
    j["Orientation"]=j["Orientation"].replace("+","+1")
    time.sleep(0.1)
# Out:
# 100%|█████████████████████████████████████████| 455/455 [00:48<00:00,  9.44it/s]

# %%
# Adding two new columns 1> Modified Locus tag and 2> contig to extract the right neighbors #
for k,v in datadict.items():
    newcon=[]
    for i in v["Contig"]:
        head,sep,tail=i.partition("_")
        newcon.append(head)
    v['req_cont']=newcon    #adding a new column "req_cont" into dataframe
    v['Locus_Tag'],v["Best_Hit_ARO"]=locus_generator(v,k)

# %%
# Read the .gnk file data, store the info in the sorted order in dictionaries #
gbk_names=[]
uniquenames=[]
datasetslist=[]
gbkdict={}
uniquedict={}

# %%
#for i in sorted(gbkfiles):    
    #gbk_names.append(os.path.basename(i).split(".")[0])
#for i in gbk_names:
    #uniquenames.append(str(i))
    #datasetslist.append(str(i))
gbk_names=filenames
uniquenames=gbk_names
datasetslist=gbk_names

# %%
#gbkfiles=sorted(gbkfiles) #read the files in the sorted order
path = '/home/amjad/NICHEnbhd/allgbksrequired/'
ext ='.gbk'
gbkfiles = (path + pd.Series(filenames) + ext).tolist()

# %%
len(datadict)
# Out:
# 455

# %%
for i in range(len(gbk_names)):
    a=gbk_names[i]
    b=uniquenames[i]
    gbkdict[a],uniquedict[b]=extract(gbkfiles[i])

# %%
len(datasetslist)
# Out:
# 455

# %%
# Convert the Locus tag column from  ['SA200015_0001'] --> SA200015_001 to help while writing to fasta file required to BLAST #
for j,i in gbkdict.items():
    i['Locus_Tag']=i['Locus_Tag'].apply(lambda i:str(i).replace("[","").replace("]","").replace("'",""))
    i['ProteinSequence']=i['ProteinSequence'].str.strip('[]')

# %%
# To supress the warning that arise when a single value of dataframe column is manipulated #
def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
pd.set_option('mode.chained_assignment', None)

# %%
# The block that causes the chained assignment error #

for i,j in tqdm(gbkdict.items()):
    for value in range(len(j["GeneName"])):
        if isinstance(j["GeneName"].iloc[value], list):
            j["GeneName"].iloc[value] = j["GeneName"].iloc[value][0]
    time.sleep(0.1)
# Out:
# 100%|█████████████████████████████████████████| 455/455 [03:32<00:00,  2.14it/s]

# %%
# For each .gbk file, divides the data based on available contigs using groupby and dictionary, used to find the neighbors of same contig# 
datasetdict={}
for i in tqdm(range(len(gbk_names))):
    for j,k in gbkdict.items():
        datasetdict[j]=make_groups(k,"contig_name")
    time.sleep(0.1)
# Out:
# 100%|█████████████████████████████████████████| 455/455 [17:54<00:00,  2.36s/it]

# %%
# Finds the union of all the AMR genes present in more than 25 percent of the total genomes #
uniquedrugdict={}
unionofdrugclasess=[]

for j,k in tqdm(datadict.items()):
    uniquedrugclasses=[]
    for l in range(len(k)):
        if k['Best_Hit_ARO'][l]  not in uniquedrugclasses:
                uniquedrugclasses.append(k["Best_Hit_ARO"][l])
    
    uniquedrugdict[j]=uniquedrugclasses
    time.sleep(0.1)
        
for i,j in tqdm(uniquedrugdict.items()):
    for item in j:
        if item not in unionofdrugclasess:
            unionofdrugclasess.append(item)
    time.sleep(0.1)
# Out:
# 100%|█████████████████████████████████████████| 455/455 [00:45<00:00,  9.92it/s]
# 100%|█████████████████████████████████████████| 455/455 [00:45<00:00,  9.93it/s]

# %%
# Converts the longer AMR gene names into shorter version to make them as dictionary keys and to make it easier to visualize in gene order image#
# Haemophilis influenzea PBP3 --> Hi_PBP3#

listofdrugnames_modified=[]
for k in unionofdrugclasess:
    if len(k.split(" "))>1:
        temp=k.split(" ")
        listofdrugnames_modified.append(temp[0][0]+temp[1][0]+"_"+temp[2])
    else:

        listofdrugnames_modified.append(k.split("; ")[0].split(" ")[0])

# %%
# A main dictionary of all the AMR models with all the genomes 
main_dictionary={}
for i in tqdm(range(len(listofdrugnames_modified))):
    main_dictionary[listofdrugnames_modified[i]]=createeachdict_drug(unionofdrugclasess[i])
    time.sleep(0.1)
# Out:
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  2.59it/s]

# %%
Dict_multigene_instances={}
Dict_singlegene_instances={}
for i,j in tqdm(main_dictionary.items()):
    temp={}
    flag=0
    for a,b in j.items():
        
        if len(b)>1:
            flag=1
    if flag==1:
        Dict_multigene_instances[i]=j
    else:
        Dict_singlegene_instances[i]=j
    time.sleep(0.1)
# Out:
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  9.85it/s]

# %%
dict_rgi_single_occurance={}
g={}
for i,j in Dict_singlegene_instances.items():
    temp={}
    l=[]
    deletekeylist=[]
    for a,b in j.items():
        if len(b)==1:
            l.append(a)
            b.reset_index(drop=True, inplace=True)            
            x=make_groups(b,"Locus_Tag")
            for e,f in x.items():
                temp[e]=f

    dict_rgi_single_occurance[i]=temp
    g[i]=l
 
for i,j in Dict_singlegene_instances.items():
    for t in g[i]:
        del j[t]
        
for i,j in dict_rgi_single_occurance.items():    
     j.update(Dict_singlegene_instances[i])

# %%
singleinstance_neighboringdict_combined_range10={}
Single_contig_end_flag_dict={}
for i,j in dict_rgi_single_occurance.items():
    Dict_neighboring_genes_range10={}
    temp_contig_flag={}
    for k,l in j.items():
        key=k.split("(")[0]
        temp,contigflag=find_neighbor(j[k],uniquedict[key],datasetdict[key],10,i,k,key,"Single_Instance_Neighborhood")
        if len(temp)>0:
            Dict_neighboring_genes_range10[k]=temp
            temp_contig_flag[k]=contigflag
    singleinstance_neighboringdict_combined_range10[i]=Dict_neighboring_genes_range10
    Single_contig_end_flag_dict[i]=temp_contig_flag

# %%
# Code to extract the locus tags, protein sequences and gene names to use to later for comparison #
Drug_singleinstance_range_10_locus_dict10={}
Drug_singleinstance_range_10_protein_dict10={}
Drug_singleinstance_range_10_genename_dict10={}

for i,j in singleinstance_neighboringdict_combined_range10.items():
    locustags_dict_10={}
    protein_dict_10={}
    genename_dict_10={}
    for k,l in j.items():
        locustags_dict_10[k],protein_dict_10[k],genename_dict_10[k]=getrequiredgenes(j[k],10,i)  
    Drug_singleinstance_range_10_locus_dict10[i]=locustags_dict_10
    Drug_singleinstance_range_10_protein_dict10[i]=protein_dict_10
    Drug_singleinstance_range_10_genename_dict10[i]=genename_dict_10

# %%
# Read the .txt files of BLAST results and store in a dictionary ######
filepath_single='/home/amjad/NICHEamrnbhd/Outputs/Single_instance/output_blast_single_instance'
Single_instance_blastdataframelist=[]
Single_instance_blastfilename=[]
readfiles=glob.glob(os.path.join(filepath_single,"*.txt"))

# %%
for i in readfiles:    
    Single_instance_blastfilename.append(os.path.basename(i).split(".")[0])
    i=pd.read_csv(i,index_col = False,sep="\t", names=['query_id','sub_id','PI','len','Evalue','bitscore','qseq','sseq'])
    Single_instance_blastdataframelist.append(i)
temp_Single_instance_blastdatadict={}### dictionary of dataframes with keys as filenames ###
for i in range(len(Single_instance_blastfilename)):
    a=Single_instance_blastdataframelist[i]
    b=Single_instance_blastfilename[i]
    temp_Single_instance_blastdatadict[b]=pd.DataFrame(a)

# %%
# To sort and filter only those BLAST results with more than 70 percent identity 

Single_instance_blastdatadict={}
for i,j in temp_Single_instance_blastdatadict.items():
    j=j[j["PI"]>70]
    Single_instance_blastdatadict[i]=j

# %%
# A function to normalize the bitscore values 
def normalized_bitscore(z): 
  manval=[]
  a=z[z['query_id']==z['sub_id']]
  manval=[]
  a=z[z['query_id']==z['sub_id']]
  a.reset_index(drop=True, inplace=True)
  q={}
  for i in range(len(a)):
    q[a['query_id'][i]]=a['bitscore'][i]

  for i in range(len(z)):
      manval.append(round(float(z['bitscore'][i])/q[z['query_id'][i]],3))

  z['normalized_bitscore']=manval
  return z

# %%
Single_instance_drugclass_genomedict={}
for k,l in tqdm(Drug_singleinstance_range_10_locus_dict10.items()):
    u=Single_instance_blastdatadict[k]
    temp_dict={}
    for a,b in l.items():        
        temp=[]
        u.reset_index(drop=True, inplace=True)
        for index in range (len(u)):
            if  u["query_id"][index] in b:
                temp.append((u["query_id"][index],u["sub_id"][index],u["PI"][index],u["bitscore"][index]))
                    
        
        temp_dict[a]=pd.DataFrame(temp,columns=["query_id","sub_id","PI","bitscore"])
    time.sleep(0.1)  
    Single_instance_drugclass_genomedict[k]=temp_dict
    

for i,j in tqdm(Single_instance_drugclass_genomedict.items()):
    for a,b in j.items():
        b=normalized_bitscore(b)
    time.sleep(0.1)
# Out:
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  1.99it/s]
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.41s/it]

# %%
# A function to remove BLAST entry results for same gene comparison by taking the highest bit score 
def remove_duplicates(temp):
    df=pd.DataFrame(temp,columns=["query_id","sub_id","bitscore"])
    d = df.sort_values("bitscore", ascending=False)
    d = d.drop_duplicates(['query_id'])
    d.reset_index(drop=True, inplace=True)
    
    return d

# %%
for a,b in l.items():
    print(b)
# Out:
# ['CCPDPMNJ_01747', 'CCPDPMNJ_01748', 'CCPDPMNJ_01749', 'CCPDPMNJ_01750', 'CCPDPMNJ_01751', 'CCPDPMNJ_01752', 'CCPDPMNJ_01753', 'CCPDPMNJ_01754', 'CCPDPMNJ_01755', 'CCPDPMNJ_01756', 'ERR1007500(tet(45))S_75.88', 'CCPDPMNJ_01758', 'CCPDPMNJ_01759']
# ['HAHGDHJH_02505', 'ERR370015(tet(45))S_76.22', 'HAHGDHJH_02507']
# ['PEDGKIKN_02517', 'ERR370019(tet(45))S_76.22', 'PEDGKIKN_02519']
# ['DOJCEBMK_02631', 'ERR370021(tet(45))S_76.22', 'DOJCEBMK_02633']
# ['PKGDHKJB_02738', 'ERR370023(tet(45))S_76.22']
# ['OLDPFJFF_02801', 'ERR370029(tet(45))S_76.22']
# ['OLDGAALD_02516', 'ERR370030(tet(45))S_76.22', 'OLDGAALD_02518']
# ['LGKJJGLA_02639', 'ERR370033(tet(45))S_76.35', 'LGKJJGLA_02641']
# ['NANNDKBM_02652', 'ERR374662(tet(45))S_76.22', 'NANNDKBM_02654']
# ['BMNIEDPJ_02619', 'ERR374663(tet(45))S_76.35', 'BMNIEDPJ_02621']
# ['GKNMGEEN_02682', 'ERR374674(tet(45))S_76.22', 'GKNMGEEN_02684']
# ['KMKMLNMB_02697', 'ERR374675(tet(45))S_76.22', 'KMKMLNMB_02699']
# ['POMBDFPJ_02603', 'ERR374679(tet(45))S_76.22', 'POMBDFPJ_02605']
# ['DFKEIGLN_02634', 'ERR374683(tet(45))S_76.22', 'DFKEIGLN_02636']
# ['GAOLEEJO_02640', 'ERR374685(tet(45))S_76.35', 'GAOLEEJO_02642']
# ['IKDJDNFP_02745', 'ERR374686(tet(45))S_76.22', 'IKDJDNFP_02747']
# ['DBHFGEOI_02273', 'ERR374693(tet(45))S_76.22', 'DBHFGEOI_02275', 'DBHFGEOI_02276', 'DBHFGEOI_02277', 'DBHFGEOI_02278', 'DBHFGEOI_02279']
# ['JEDJFBAF_02359', 'ERR374696(tet(45))S_76.22', 'JEDJFBAF_02361', 'JEDJFBAF_02362', 'JEDJFBAF_02363', 'JEDJFBAF_02364', 'JEDJFBAF_02365']
# ['BELELGNH_02712', 'ERR374697(tet(45))S_76.22', 'BELELGNH_02714']
# ['ERR374701(tet(45))S_76.22', 'NIHPGBGP_02752']
# ['HFHACNEE_02284', 'HFHACNEE_02285', 'HFHACNEE_02286', 'HFHACNEE_02287', 'HFHACNEE_02288', 'HFHACNEE_02289', 'HFHACNEE_02290', 'ERR374703(tet(45))S_76.22', 'HFHACNEE_02292']
# ['KPKDEINB_02813', 'ERR374707(tet(45))S_76.35', 'KPKDEINB_02815']
# ['LCOHDJCF_02437', 'LCOHDJCF_02438', 'LCOHDJCF_02439', 'LCOHDJCF_02440', 'LCOHDJCF_02441', 'ERR374718(tet(45))S_76.22', 'LCOHDJCF_02443']
# ['NKKGBBMN_02582', 'ERR374721(tet(45))S_76.22', 'NKKGBBMN_02584']
# ['EOEINOFD_02618', 'ERR374723(tet(45))S_76.35', 'EOEINOFD_02620']
# ['DFOOCDFE_02498', 'ERR374724(tet(45))S_76.22', 'DFOOCDFE_02500']
# ['PIBCPLLM_02305', 'ERR374725(tet(45))S_76.22', 'PIBCPLLM_02307', 'PIBCPLLM_02308', 'PIBCPLLM_02309', 'PIBCPLLM_02310', 'PIBCPLLM_02311', 'PIBCPLLM_02312', 'PIBCPLLM_02313']
# ['NLOLMPFE_02669', 'ERR374821(tet(45))S_76.35', 'NLOLMPFE_02671']
# ['DJIPPCOC_02589', 'ERR374824(tet(45))S_76.35', 'DJIPPCOC_02591']
# ['PJLOECDD_02643', 'ERR374826(tet(45))S_76.22', 'PJLOECDD_02645']
# ['DAIMEFLD_02849', 'ERR374828(tet(45))S_76.35']
# ['OIOKFAOL_02614', 'ERR374829(tet(45))S_76.22', 'OIOKFAOL_02616']
# ['GPPOHLEE_02697', 'ERR374832(tet(45))S_76.83']
# ['OOHBNCGE_02213', 'OOHBNCGE_02214', 'OOHBNCGE_02215', 'OOHBNCGE_02216', 'OOHBNCGE_02217', 'OOHBNCGE_02218', 'OOHBNCGE_02219', 'ERR374836(tet(45))S_76.22', 'OOHBNCGE_02221']
# ['ELNLEPGO_02544', 'ERR374843(tet(45))S_76.22', 'ELNLEPGO_02546']
# ['GJAMOBJN_02630', 'ERR374848(tet(45))S_76.22', 'GJAMOBJN_02632']
# ['EKGGMHEM_02714', 'ERR374849(tet(45))S_76.22', 'EKGGMHEM_02716']
# ['MIHOOICH_02632', 'ERR374855(tet(45))S_76.22', 'MIHOOICH_02634']
# ['HLACIPNI_02614', 'ERR374856(tet(45))S_76.83']
# ['CLCOOGCD_02768', 'ERR374864(tet(45))S_76.22', 'CLCOOGCD_02770']
# ['ODBJEHIL_01432', 'ODBJEHIL_01433', 'ODBJEHIL_01434', 'ODBJEHIL_01435', 'ODBJEHIL_01436', 'ODBJEHIL_01437', 'ODBJEHIL_01438', 'ODBJEHIL_01439', 'ODBJEHIL_01440', 'ODBJEHIL_01441', 'ERR374867(tet(45))S_76.22', 'ODBJEHIL_01443']
# ['KNHMBHCH_02591', 'ERR374871(tet(45))S_76.22', 'KNHMBHCH_02593']
# ['CAGGKJIJ_02591', 'ERR374882(tet(45))S_76.22', 'CAGGKJIJ_02593']
# ['DNMHPPND_02513', 'ERR374883(tet(45))S_76.22', 'DNMHPPND_02515']
# ['EAJHLMMI_02596', 'ERR374894(tet(45))S_76.22', 'EAJHLMMI_02598']
# ['NEKNDMKO_01556', 'NEKNDMKO_01557', 'NEKNDMKO_01558', 'NEKNDMKO_01559', 'NEKNDMKO_01560', 'NEKNDMKO_01561', 'NEKNDMKO_01562', 'NEKNDMKO_01563', 'NEKNDMKO_01564', 'NEKNDMKO_01565', 'ERR374898(tet(45))S_76.22', 'NEKNDMKO_01567']
# ['EHKGOCNN_02520', 'ERR374907(tet(45))S_76.22', 'EHKGOCNN_02522']
# ['IIHOGBBA_02679', 'ERR374909(tet(45))S_76.35', 'IIHOGBBA_02681']
# ['ERR374912(tet(45))S_78.86']
# ['ERR374913(tet(45))S_76.22', 'BNHHMKDJ_02714']
# ['HAEBNPGA_02613', 'ERR374919(tet(45))S_76.22', 'HAEBNPGA_02615']
# ['ILBGALCL_00904', 'ERR374920(tet(45))S_76.22', 'ILBGALCL_00906', 'ILBGALCL_00907', 'ILBGALCL_00908', 'ILBGALCL_00909', 'ILBGALCL_00910', 'ILBGALCL_00911', 'ILBGALCL_00912', 'ILBGALCL_00913', 'ILBGALCL_00914', 'ILBGALCL_00915']
# ['LDALEMMP_02648', 'ERR374921(tet(45))S_76.35', 'LDALEMMP_02650']
# ['JHFFFOIA_02525', 'ERR374924(tet(45))S_76.22', 'JHFFFOIA_02527']
# ['HNCIBHIM_02474', 'ERR374929(tet(45))S_76.22', 'HNCIBHIM_02476']
# ['HOPKJDIP_02546', 'ERR374930(tet(45))S_76.22', 'HOPKJDIP_02548']
# ['AOEJNLJH_02703', 'ERR374933(tet(45))S_76.35', 'AOEJNLJH_02705']
# ['GPILNEKI_02559', 'ERR374938(tet(45))S_76.22', 'GPILNEKI_02561']
# ['GICCJLIP_02772', 'ERR374939(tet(45))S_76.22', 'GICCJLIP_02774']
# ['LAMIDKMA_02667', 'ERR374940(tet(45))S_76.35', 'LAMIDKMA_02669']
# ['NCCMBHEL_02682', 'ERR374944(tet(45))S_76.22', 'NCCMBHEL_02684']
# ['IKBMMMHM_02808', 'ERR374947(tet(45))S_76.22', 'IKBMMMHM_02810']
# ['KHAKMHHN_02645', 'ERR374949(tet(45))S_76.22', 'KHAKMHHN_02647']
# ['ERR374952(tet(45))S_76.35', 'CCLAMMEI_02674']
# ['NLCGDFLC_02650', 'ERR374956(tet(45))S_76.35', 'NLCGDFLC_02652', 'NLCGDFLC_02653']
# ['PGFNANML_02761', 'ERR374963(tet(45))S_76.35', 'PGFNANML_02763']
# ['ODILCLME_02744', 'ERR374965(tet(45))S_76.22', 'ODILCLME_02746']
# ['DMDPKPPM_02638', 'ERR374971(tet(45))S_76.22', 'DMDPKPPM_02640']
# ['BKACPFNN_02635', 'ERR374972(tet(45))S_76.35', 'BKACPFNN_02637']
# ['APLFMNEM_02456', 'APLFMNEM_02457', 'APLFMNEM_02458', 'APLFMNEM_02459', 'APLFMNEM_02460', 'ERR374978(tet(45))S_76.22', 'APLFMNEM_02462']
# ['PFFFGLLK_02610', 'ERR374979(tet(45))S_76.35', 'PFFFGLLK_02612']
# ['MLAHHJNN_02720', 'ERR374982(tet(45))S_76.35', 'MLAHHJNN_02722']
# ['MMODLCDL_02212', 'ERR374986(tet(45))S_76.22', 'MMODLCDL_02214', 'MMODLCDL_02215', 'MMODLCDL_02216', 'MMODLCDL_02217', 'MMODLCDL_02218', 'MMODLCDL_02219', 'MMODLCDL_02220']
# ['MELKFEHF_02732', 'ERR374990(tet(45))S_76.35', 'MELKFEHF_02734']
# ['HGAHFCME_02661', 'ERR374992(tet(45))S_76.22', 'HGAHFCME_02663']
# ['GAKCDMHG_02622', 'ERR374993(tet(45))S_76.22', 'GAKCDMHG_02624']
# ['MGGOENIP_02538', 'ERR374995(tet(45))S_76.35', 'MGGOENIP_02540']
# ['CPCEAGAP_02745', 'ERR374998(tet(45))S_76.35', 'CPCEAGAP_02747']
# ['FKJIDBCF_02247', 'ERR375001(tet(45))S_76.22', 'FKJIDBCF_02249', 'FKJIDBCF_02250', 'FKJIDBCF_02251', 'FKJIDBCF_02252', 'FKJIDBCF_02253', 'FKJIDBCF_02254', 'FKJIDBCF_02255']
# ['CLHCABFF_02268', 'ERR375005(tet(45))S_76.22', 'CLHCABFF_02270', 'CLHCABFF_02271', 'CLHCABFF_02272', 'CLHCABFF_02273', 'CLHCABFF_02274']
# ['EDNOEPND_02600', 'ERR375010(tet(45))S_76.22', 'EDNOEPND_02602']
# ['OIKJAMNL_02793', 'ERR375013(tet(45))S_76.35', 'OIKJAMNL_02795']
# ['DPCIFHFP_02565', 'ERR375014(tet(45))S_76.35', 'DPCIFHFP_02567']
# ['AFLGDNKP_02664', 'ERR375015(tet(45))S_76.22', 'AFLGDNKP_02666']
# ['GLGGBEFF_02744', 'ERR375018(tet(45))S_76.22', 'GLGGBEFF_02746']
# ['INFMPKCE_02696', 'ERR375019(tet(45))S_76.22']
# ['NAOKECPG_02641', 'ERR375022(tet(45))S_76.22', 'NAOKECPG_02643']
# ['JDKNFNIJ_02727', 'ERR375023(tet(45))S_76.22', 'JDKNFNIJ_02729']
# ['MIBMEDLB_02297', 'MIBMEDLB_02298', 'MIBMEDLB_02299', 'MIBMEDLB_02300', 'MIBMEDLB_02301', 'MIBMEDLB_02302', 'MIBMEDLB_02303', 'ERR375024(tet(45))S_76.22', 'MIBMEDLB_02305']
# ['PFFBGFKG_02767', 'ERR375027(tet(45))S_76.22']
# ['GNIAIDAG_02705', 'ERR375028(tet(45))S_76.22', 'GNIAIDAG_02707']
# ['OPCHJOJG_02633', 'ERR375030(tet(45))S_76.22', 'OPCHJOJG_02635']
# ['AACAMKEI_02632', 'ERR375031(tet(45))S_76.22', 'AACAMKEI_02634']
# ['JGGMMHLN_02308', 'ERR375033(tet(45))S_76.22', 'JGGMMHLN_02310', 'JGGMMHLN_02311', 'JGGMMHLN_02312', 'JGGMMHLN_02313', 'JGGMMHLN_02314', 'JGGMMHLN_02315', 'JGGMMHLN_02316']
# ['KNANIHKK_02632', 'ERR375035(tet(45))S_76.22', 'KNANIHKK_02634']
# ['JJGPAKPM_02677', 'ERR375042(tet(45))S_76.35', 'JJGPAKPM_02679']
# ['HPGPCOGO_02654', 'ERR375046(tet(45))S_76.35', 'HPGPCOGO_02656']
# ['NDJDANNE_02514', 'ERR375051(tet(45))S_76.35', 'NDJDANNE_02516']
# ['PIKDGOBH_02601', 'ERR375052(tet(45))S_76.35', 'PIKDGOBH_02603']
# ['FJAGLBNG_02637', 'ERR375056(tet(45))S_76.35', 'FJAGLBNG_02639']
# ['BMHADFIP_02600', 'ERR375057(tet(45))S_76.22', 'BMHADFIP_02602']
# ['NJGBFGEB_02596', 'NJGBFGEB_02597', 'ERR375060(tet(45))S_67.25', 'NJGBFGEB_02599', 'NJGBFGEB_02600']
# ['GHLFKOJA_02582', 'ERR375062(tet(45))S_76.22', 'GHLFKOJA_02584']
# ['EAFGFAGM_02627', 'ERR375066(tet(45))S_76.35', 'EAFGFAGM_02629']
# ['EDINFLIO_02687', 'ERR375070(tet(45))S_76.35', 'EDINFLIO_02689']
# ['BDMLJDNB_02609', 'ERR375071(tet(45))S_76.22', 'BDMLJDNB_02611']
# ['NAPMJGKH_02642', 'ERR375075(tet(45))S_76.22', 'NAPMJGKH_02644']
# ['ELOPGLNI_02699', 'ERR375079(tet(45))S_76.22', 'ELOPGLNI_02701']
# ['DENBMMEN_02648', 'ERR375083(tet(45))S_76.22', 'DENBMMEN_02650']
# ['HGHIDLDM_02772', 'ERR375090(tet(45))S_76.35']
# ['ERR375091(tet(45))S_78.86']
# ['CAMGHMPD_02527', 'ERR375094(tet(45))S_76.22', 'CAMGHMPD_02529']
# ['NGGKIEDB_02634', 'ERR375097(tet(45))S_76.35', 'NGGKIEDB_02636']
# ['EEGOCIBD_02609', 'ERR375105(tet(45))S_76.22', 'EEGOCIBD_02611']
# ['EIMGNMOE_02819', 'ERR375109(tet(45))S_76.35', 'EIMGNMOE_02821']
# ['DLOOILJE_02659', 'ERR375114(tet(45))S_76.22', 'DLOOILJE_02661']
# ['HAEKODAB_02622', 'ERR375129(tet(45))S_76.35', 'HAEKODAB_02624']
# ['LDFGELBD_02609', 'ERR375130(tet(45))S_76.22', 'LDFGELBD_02611']
# ['OAFDHCCA_02671', 'ERR375133(tet(45))S_76.35', 'OAFDHCCA_02673']
# ['OFLLFDBK_02625', 'ERR375135(tet(45))S_76.22', 'OFLLFDBK_02627']
# ['HFCPEDNG_02366', 'ERR375136(tet(45))S_76.22', 'HFCPEDNG_02368', 'HFCPEDNG_02369', 'HFCPEDNG_02370', 'HFCPEDNG_02371', 'HFCPEDNG_02372']
# ['HAIAAKIL_02608', 'ERR375137(tet(45))S_76.35', 'HAIAAKIL_02610']
# ['PEDLFJHF_02606', 'ERR375138(tet(45))S_76.22', 'PEDLFJHF_02608']
# ['JNLDDBDA_02740', 'ERR375143(tet(45))S_76.22', 'JNLDDBDA_02742']
# ['KLJCHFME_02292', 'ERR375145(tet(45))S_76.35', 'KLJCHFME_02294', 'KLJCHFME_02295', 'KLJCHFME_02296', 'KLJCHFME_02297', 'KLJCHFME_02298']
# ['MEHBHLLJ_02198', 'ERR375148(tet(45))S_76.22', 'MEHBHLLJ_02200', 'MEHBHLLJ_02201', 'MEHBHLLJ_02202', 'MEHBHLLJ_02203', 'MEHBHLLJ_02204']
# ['GGKIHAOA_02632', 'ERR375153(tet(45))S_76.22', 'GGKIHAOA_02634']
# ['KFFAFNBL_02879', 'ERR375157(tet(45))S_76.35', 'KFFAFNBL_02881']
# ['KANGFHKO_02599', 'ERR375160(tet(45))S_76.35', 'KANGFHKO_02601']
# ['NBAKKMBK_02674', 'ERR375161(tet(45))S_76.22', 'NBAKKMBK_02676']
# ['ODPLOAIA_00922', 'ODPLOAIA_00923', 'ODPLOAIA_00924', 'ODPLOAIA_00925', 'ODPLOAIA_00926', 'ODPLOAIA_00927', 'ODPLOAIA_00928', 'ODPLOAIA_00929', 'ODPLOAIA_00930', 'ODPLOAIA_00931', 'ERR375177(tet(45))S_76.22', 'ODPLOAIA_00933']
# ['EJMBFOKK_01471', 'ERR375279(tet(45))S_76.22', 'EJMBFOKK_01473', 'EJMBFOKK_01474', 'EJMBFOKK_01475', 'EJMBFOKK_01476', 'EJMBFOKK_01477', 'EJMBFOKK_01478', 'EJMBFOKK_01479', 'EJMBFOKK_01480', 'EJMBFOKK_01481', 'EJMBFOKK_01482']
# ['IBFKJBDL_01810', 'ERR375283(tet(45))S_76.22', 'IBFKJBDL_01812', 'IBFKJBDL_01813', 'IBFKJBDL_01814', 'IBFKJBDL_01815', 'IBFKJBDL_01816', 'IBFKJBDL_01817', 'IBFKJBDL_01818', 'IBFKJBDL_01819', 'IBFKJBDL_01820', 'IBFKJBDL_01821']
# ['GPOIJKCB_02436', 'GPOIJKCB_02437', 'GPOIJKCB_02438', 'GPOIJKCB_02439', 'GPOIJKCB_02440', 'ERR375284(tet(45))S_76.22', 'GPOIJKCB_02442']
# ['HGPEMFNB_01031', 'ERR375305(tet(45))S_76.22', 'HGPEMFNB_01033', 'HGPEMFNB_01034', 'HGPEMFNB_01035', 'HGPEMFNB_01036', 'HGPEMFNB_01037', 'HGPEMFNB_01038', 'HGPEMFNB_01039', 'HGPEMFNB_01040', 'HGPEMFNB_01041', 'HGPEMFNB_01042']
# ['IKHFIGGP_02738', 'ERR375311(tet(45))S_76.22', 'IKHFIGGP_02740']
# ['LJMDDGMA_02660', 'ERR375313(tet(45))S_76.22', 'LJMDDGMA_02662']
# ['MAMKIMOK_02726', 'ERR375316(tet(45))S_76.35', 'MAMKIMOK_02728']
# ['JPMNKMHK_02712', 'ERR375318(tet(45))S_76.22', 'JPMNKMHK_02714']
# ['DBGNBHHB_02474', 'DBGNBHHB_02475', 'DBGNBHHB_02476', 'DBGNBHHB_02477', 'DBGNBHHB_02478', 'DBGNBHHB_02479', 'DBGNBHHB_02480', 'DBGNBHHB_02481', 'DBGNBHHB_02482', 'DBGNBHHB_02483', 'ERR375323(tet(45))S_77.75', 'DBGNBHHB_02485', 'DBGNBHHB_02486']
# ['CJBIBINP_02896', 'ERR375330(tet(45))S_76.22', 'CJBIBINP_02898']
# ['MOJKAGKJ_02718', 'ERR375333(tet(45))S_76.22']
# ['ERR375335(tet(45))S_76.22', 'JFCENOLB_02756']
# ['GHGPEELG_02478', 'ERR375339(tet(45))S_76.35', 'GHGPEELG_02480', 'GHGPEELG_02481']
# ['IIOJAMON_02375', 'ERR375358(tet(45))S_76.22', 'IIOJAMON_02377', 'IIOJAMON_02378', 'IIOJAMON_02379', 'IIOJAMON_02380', 'IIOJAMON_02381']
# ['ERR375360(tet(45))S_76.22', 'NCIFCNIL_02695']
# ['MFIBIBPH_02610', 'ERR375365(tet(45))S_76.22', 'MFIBIBPH_02612']
# ['HNPNLCAC_02696', 'ERR375371(tet(45))S_76.35', 'HNPNLCAC_02698']
# ['BMJBNDLH_02625', 'ERR375382(tet(45))S_76.22', 'BMJBNDLH_02627']
# ['BGPGEOAD_02692', 'ERR375392(tet(45))S_76.35']
# ['ACMLNABJ_02669', 'ERR375394(tet(45))S_76.35', 'ACMLNABJ_02671']
# ['DFIHNFNI_02375', 'ERR375406(tet(45))S_76.22', 'DFIHNFNI_02377', 'DFIHNFNI_02378', 'DFIHNFNI_02379', 'DFIHNFNI_02380', 'DFIHNFNI_02381']
# ['ERR375409(tet(45))S_76.22', 'GOHJEGJH_02731']
# ['NJKBINDF_01030', 'ERR375422(tet(45))S_76.22', 'NJKBINDF_01032', 'NJKBINDF_01033', 'NJKBINDF_01034', 'NJKBINDF_01035', 'NJKBINDF_01036', 'NJKBINDF_01037', 'NJKBINDF_01038', 'NJKBINDF_01039', 'NJKBINDF_01040', 'NJKBINDF_01041']
# ['PCHMDBBF_02267', 'ERR375425(tet(45))S_76.22', 'PCHMDBBF_02269', 'PCHMDBBF_02270', 'PCHMDBBF_02271', 'PCHMDBBF_02272', 'PCHMDBBF_02273', 'PCHMDBBF_02274', 'PCHMDBBF_02275']
# ['JJJCPLKG_02653', 'ERR375427(tet(45))S_76.22', 'JJJCPLKG_02655']
# ['KBHHKMIP_02614', 'ERR375430(tet(45))S_76.22', 'KBHHKMIP_02616']
# ['BILMHGAO_02665', 'ERR375434(tet(45))S_76.22', 'BILMHGAO_02667']
# ['MCCECALG_02703', 'ERR375436(tet(45))S_76.22', 'MCCECALG_02705']
# ['NMCCCOEG_00828', 'NMCCCOEG_00829', 'NMCCCOEG_00830', 'NMCCCOEG_00831', 'NMCCCOEG_00832', 'NMCCCOEG_00833', 'NMCCCOEG_00834', 'NMCCCOEG_00835', 'NMCCCOEG_00836', 'NMCCCOEG_00837', 'ERR375440(tet(45))S_76.22', 'NMCCCOEG_00839']
# ['JNLBNJPF_02644', 'ERR375452(tet(45))S_76.22', 'JNLBNJPF_02646']
# ['ONMLLEJO_02303', 'ERR375473(tet(45))S_76.22', 'ONMLLEJO_02305', 'ONMLLEJO_02306', 'ONMLLEJO_02307', 'ONMLLEJO_02308', 'ONMLLEJO_02309', 'ONMLLEJO_02310', 'ONMLLEJO_02311']
# ['DCDEAFGP_02369', 'DCDEAFGP_02370', 'DCDEAFGP_02371', 'DCDEAFGP_02372', 'DCDEAFGP_02373', 'ERR375476(tet(45))S_76.22', 'DCDEAFGP_02375']
# ['NKLGOLDK_02619', 'ERR375480(tet(45))S_76.22', 'NKLGOLDK_02621']
# ['ERR375481(tet(45))S_76.22', 'OOKEHFGF_02814']
# ['BGJJCBIA_02874', 'ERR375483(tet(45))S_76.22', 'BGJJCBIA_02876']
# ['EHCDDHOI_02771', 'ERR375494(tet(45))S_76.22', 'EHCDDHOI_02773']
# ['GGEAEOMM_02848', 'ERR375496(tet(45))S_76.22', 'GGEAEOMM_02850']
# ['KEFFFNBE_02648', 'ERR375497(tet(45))S_76.22', 'KEFFFNBE_02650']
# ['FONJPIEB_02897', 'ERR375498(tet(45))S_76.22', 'FONJPIEB_02899']
# ['BCOJHLPM_02757', 'ERR375506(tet(45))S_76.22', 'BCOJHLPM_02759']
# ['OPJNFDGK_02604', 'ERR375512(tet(45))S_76.22', 'OPJNFDGK_02606']
# ['MGEJDKMH_02772', 'ERR375515(tet(45))S_76.35', 'MGEJDKMH_02774']
# ['NMGIPCBK_02599', 'ERR375529(tet(45))S_76.22', 'NMGIPCBK_02601']
# ['OOAEGOMB_02588', 'OOAEGOMB_02589', 'OOAEGOMB_02590', 'OOAEGOMB_02591', 'OOAEGOMB_02592', 'OOAEGOMB_02593', 'OOAEGOMB_02594', 'ERR375530(tet(45))S_76.35', 'OOAEGOMB_02596']
# ['JODJCKMD_02362', 'ERR375542(tet(45))S_76.22', 'JODJCKMD_02364', 'JODJCKMD_02365', 'JODJCKMD_02366', 'JODJCKMD_02367', 'JODJCKMD_02368']
# ['ERR375544(tet(45))S_76.22', 'BABNHDDK_02650']
# ['GJGCFDLB_02678', 'ERR375553(tet(45))S_76.22', 'GJGCFDLB_02680']
# ['ERR375556(tet(45))S_76.22', 'MBPPELBE_02614']
# ['HCKBPLGP_02810', 'ERR377425(tet(45))S_76.22', 'HCKBPLGP_02812']
# ['EBOIMECL_02811', 'ERR377436(tet(45))S_76.35', 'EBOIMECL_02813']
# ['ERR377437(tet(45))S_76.22', 'JCMNALPJ_02656']
# ['ERR377438(tet(45))S_76.35', 'FCLEKIGM_02818']
# ['OAGBDLLP_02701', 'OAGBDLLP_02702', 'OAGBDLLP_02703', 'OAGBDLLP_02704', 'OAGBDLLP_02705', 'ERR377440(tet(45))S_76.22', 'OAGBDLLP_02707']
# ['BMDNADIO_00943', 'BMDNADIO_00944', 'BMDNADIO_00945', 'BMDNADIO_00946', 'BMDNADIO_00947', 'BMDNADIO_00948', 'BMDNADIO_00949', 'BMDNADIO_00950', 'BMDNADIO_00951', 'BMDNADIO_00952', 'ERR377443(tet(45))S_76.22', 'BMDNADIO_00954']
# ['PDDMEENP_02627', 'ERR377444(tet(45))S_76.22']
# ['ACOIAFBD_02583', 'ERR377446(tet(45))S_76.35', 'ACOIAFBD_02585']
# ['GHNJCODC_02526', 'ERR377454(tet(45))S_76.35', 'GHNJCODC_02528']
# ['FIJGNEEP_02757', 'ERR377458(tet(45))S_76.22']
# ['ERR377465(tet(45))S_76.22', 'HENKDCGM_02698']
# ['IONDMGKF_02344', 'IONDMGKF_02345', 'IONDMGKF_02346', 'IONDMGKF_02347', 'IONDMGKF_02348', 'ERR377468(tet(45))S_76.22', 'IONDMGKF_02350']
# ['PMNHJFLP_02687', 'ERR377469(tet(45))S_76.0', 'PMNHJFLP_02689']
# ['ERR377474(tet(45))S_76.22', 'BEGLFNJA_02810']
# ['DDPAJLLM_02380', 'ERR377478(tet(45))S_76.22', 'DDPAJLLM_02382', 'DDPAJLLM_02383', 'DDPAJLLM_02384', 'DDPAJLLM_02385', 'DDPAJLLM_02386']
# ['PKOIOLOL_02554', 'ERR377481(tet(45))S_76.35', 'PKOIOLOL_02556']
# ['EDOEMAPL_02707', 'ERR377483(tet(45))S_76.22', 'EDOEMAPL_02709']
# ['LBBMDPKI_02749', 'ERR377484(tet(45))S_76.35']
# ['FEKCGEPO_02500', 'ERR377485(tet(45))S_76.22', 'FEKCGEPO_02502']
# ['ERR377501(tet(45))S_76.35', 'LJENHIIC_02762']
# ['LEGKEHIN_02370', 'ERR377510(tet(45))S_76.22', 'LEGKEHIN_02372', 'LEGKEHIN_02373', 'LEGKEHIN_02374', 'LEGKEHIN_02375', 'LEGKEHIN_02376']
# ['KBDDCKAE_02656', 'ERR388688(tet(45))S_76.35', 'KBDDCKAE_02658']
# ['DODPHKBF_02536', 'ERR388689(tet(45))S_76.22', 'DODPHKBF_02538']
# ['GINMANIL_02829', 'ERR388691(tet(45))S_76.35', 'GINMANIL_02831']
# ['FDKANIPL_02580', 'ERR388692(tet(45))S_76.22', 'FDKANIPL_02582']
# ['CCDCMIBA_02626', 'ERR388693(tet(45))S_76.22', 'CCDCMIBA_02628']
# ['ERR388694(tet(45))S_76.22', 'CMFHFKLA_02585']
# ['ICOMKICB_02623', 'ERR388701(tet(45))S_76.0', 'ICOMKICB_02625']
# ['BMCKEJMC_02394', 'BMCKEJMC_02395', 'BMCKEJMC_02396', 'BMCKEJMC_02397', 'BMCKEJMC_02398', 'ERR388702(tet(45))S_76.22', 'BMCKEJMC_02400']
# ['NKPBGGDO_01030', 'ERR388703(tet(45))S_76.22', 'NKPBGGDO_01032', 'NKPBGGDO_01033', 'NKPBGGDO_01034', 'NKPBGGDO_01035', 'NKPBGGDO_01036', 'NKPBGGDO_01037', 'NKPBGGDO_01038', 'NKPBGGDO_01039', 'NKPBGGDO_01040', 'NKPBGGDO_01041']
# ['ERR388715(tet(45))S_76.63']
# ['ERR388717(tet(45))S_76.22', 'DHCDBOAH_02771']
# ['EJHCHPHG_02647', 'ERR388718(tet(45))S_76.22', 'EJHCHPHG_02649']
# ['BHONGEGO_02802', 'ERR388724(tet(45))S_76.35', 'BHONGEGO_02804']
# ['BMGCPPFN_02584', 'ERR388725(tet(45))S_76.22', 'BMGCPPFN_02586']
# ['MEBGDJFD_02691', 'MEBGDJFD_02692', 'ERR984973(tet(45))S_76.35', 'MEBGDJFD_02694']
# ['AMILDOMO_02526', 'ERR984977(tet(45))S_76.22', 'AMILDOMO_02528']
# ['DMEDGFDD_02504', 'DMEDGFDD_02505', 'DMEDGFDD_02506', 'DMEDGFDD_02507', 'DMEDGFDD_02508', 'DMEDGFDD_02509', 'DMEDGFDD_02510', 'ERR984981(tet(45))S_76.22', 'DMEDGFDD_02512']
# ['MMOMICNB_02612', 'ERR984985(tet(45))S_76.22', 'MMOMICNB_02614']
# ['EMKOBIDN_02464', 'ERR984986(tet(45))S_76.22', 'EMKOBIDN_02466']
# ['DMGHLJEP_02643', 'ERR984987(tet(45))S_76.22', 'DMGHLJEP_02645']
# ['MFJNMAEL_00517', 'MFJNMAEL_00518', 'MFJNMAEL_00519', 'MFJNMAEL_00520', 'MFJNMAEL_00521', 'MFJNMAEL_00522', 'MFJNMAEL_00523', 'MFJNMAEL_00524', 'MFJNMAEL_00525', 'MFJNMAEL_00526', 'ERR984996(tet(45))S_76.22', 'MFJNMAEL_00528', 'MFJNMAEL_00529', 'MFJNMAEL_00530', 'MFJNMAEL_00531', 'MFJNMAEL_00532', 'MFJNMAEL_00533', 'MFJNMAEL_00534']
# ['NJAAKKCE_02612', 'ERR987562(tet(45))S_76.35', 'NJAAKKCE_02614']
# ['POLCBFPP_01508', 'POLCBFPP_01509', 'POLCBFPP_01510', 'POLCBFPP_01511', 'POLCBFPP_01512', 'POLCBFPP_01513', 'POLCBFPP_01514', 'POLCBFPP_01515', 'POLCBFPP_01516', 'POLCBFPP_01517', 'ERR987576(tet(45))S_76.22', 'POLCBFPP_01519']
# ['MIOEGKBC_02417', 'ERR987581(tet(45))S_76.35', 'MIOEGKBC_02419', 'MIOEGKBC_02420']
# ['OEKJFDGO_02621', 'ERR987585(tet(45))S_76.22', 'OEKJFDGO_02623']
# ['EICOFFAI_02313', 'EICOFFAI_02314', 'EICOFFAI_02315', 'EICOFFAI_02316', 'EICOFFAI_02317', 'EICOFFAI_02318', 'EICOFFAI_02319', 'ERR987586(tet(45))S_76.0', 'EICOFFAI_02321']
# ['OAIOJOOH_02739', 'ERR987592(tet(45))S_76.22', 'OAIOJOOH_02741']
# ['IGMIACBJ_02577', 'ERR987593(tet(45))S_76.0', 'IGMIACBJ_02579']
# ['GIGEABFC_02665', 'ERR987597(tet(45))S_76.22']
# ['MFCGDKMP_02583', 'ERR987600(tet(45))S_76.35', 'MFCGDKMP_02585']
# ['PDJNFGEP_02623', 'ERR987601(tet(45))S_76.22', 'PDJNFGEP_02625']
# ['PLPANPNE_02587', 'ERR987602(tet(45))S_76.22', 'PLPANPNE_02589']
# ['KLMGOMKH_02755', 'ERR987605(tet(45))S_76.22', 'KLMGOMKH_02757']
# ['OIMNBPPD_02582', 'ERR987615(tet(45))S_76.22', 'OIMNBPPD_02584']
# ['HJEHOJIP_02542', 'ERR987617(tet(45))S_76.22', 'HJEHOJIP_02544']
# ['CLLHINKM_00276', 'ERR987620(tet(45))S_76.22', 'CLLHINKM_00278', 'CLLHINKM_00279', 'CLLHINKM_00280', 'CLLHINKM_00281', 'CLLHINKM_00282', 'CLLHINKM_00283', 'CLLHINKM_00284', 'CLLHINKM_00285', 'CLLHINKM_00286', 'CLLHINKM_00287']
# ['LHFLJIFP_02572', 'ERR987626(tet(45))S_76.22', 'LHFLJIFP_02574']
# ['ODJODMFG_02095', 'ODJODMFG_02096', 'ODJODMFG_02097', 'ODJODMFG_02098', 'ODJODMFG_02099', 'ODJODMFG_02100', 'ODJODMFG_02101', 'ODJODMFG_02102', 'ODJODMFG_02103', 'ODJODMFG_02104', 'ERR987638(tet(45))S_76.35', 'ODJODMFG_02106']
# ['FGELFMJA_02566', 'ERR987639(tet(45))S_76.22', 'FGELFMJA_02568']
# ['LGFCJCBA_02291', 'LGFCJCBA_02292', 'LGFCJCBA_02293', 'LGFCJCBA_02294', 'LGFCJCBA_02295', 'ERR987640(tet(45))S_78.95']
# ['MPFGMLEJ_02306', 'MPFGMLEJ_02307', 'MPFGMLEJ_02308', 'MPFGMLEJ_02309', 'MPFGMLEJ_02310', 'SRR14010945(tet(45))S_76.22', 'MPFGMLEJ_02312']
# ['PMGBFIIN_01604', 'PMGBFIIN_01605', 'PMGBFIIN_01606', 'PMGBFIIN_01607', 'PMGBFIIN_01608', 'PMGBFIIN_01609', 'PMGBFIIN_01610', 'PMGBFIIN_01611', 'PMGBFIIN_01612', 'PMGBFIIN_01613', 'SRR14026549(tet(45))S_76.35', 'PMGBFIIN_01615']
# ['JKMJJIDI_02544', 'SRR14026551(tet(45))S_76.0', 'JKMJJIDI_02546']
# ['NDKEGGMP_02538', 'SRR14026553(tet(45))S_76.22', 'NDKEGGMP_02540']

# %%
for k, l in Drug_singleinstance_range_10_locus_dict10.items():
    print(l)
    #break
    for genome1 in Single_instance_drugclass_genomedict[k].keys():
        u =Single_instance_drugclass_genomedict[k][genome1]
        print(u)
        #break
# Out:
# {'ERR1007500(tet(45))S_75.88': ['CCPDPMNJ_01747', 'CCPDPMNJ_01748', 'CCPDPMNJ_01749', 'CCPDPMNJ_01750', 'CCPDPMNJ_01751', 'CCPDPMNJ_01752', 'CCPDPMNJ_01753', 'CCPDPMNJ_01754', 'CCPDPMNJ_01755', 'CCPDPMNJ_01756', 'ERR1007500(tet(45))S_75.88', 'CCPDPMNJ_01758', 'CCPDPMNJ_01759'], 'ERR1007501(tet(45))S_75.88': ['MOOCJHBJ_01764', 'MOOCJHBJ_01765', 'MOOCJHBJ_01766', 'MOOCJHBJ_01767', 'MOOCJHBJ_01768', 'MOOCJHBJ_01769', 'MOOCJHBJ_01770', 'MOOCJHBJ_01771', 'MOOCJHBJ_01772', 'MOOCJHBJ_01773', 'ERR1007501(tet(45))S_75.88', 'MOOCJHBJ_01775', 'MOOCJHBJ_01776'], 'ERR1036024(tet(45))S_76.35': ['CAEBHLLJ_02431', 'CAEBHLLJ_02432', 'CAEBHLLJ_02433', 'CAEBHLLJ_02434', 'ERR1036024(tet(45))S_76.35', 'CAEBHLLJ_02436', 'CAEBHLLJ_02437', 'CAEBHLLJ_02438', 'CAEBHLLJ_02439', 'CAEBHLLJ_02440', 'CAEBHLLJ_02441', 'CAEBHLLJ_02442', 'CAEBHLLJ_02443', 'CAEBHLLJ_02444', 'CAEBHLLJ_02445'], 'ERR1036025(tet(45))S_76.22': ['HMEHPJPD_02238', 'ERR1036025(tet(45))S_76.22', 'HMEHPJPD_02240', 'HMEHPJPD_02241', 'HMEHPJPD_02242', 'HMEHPJPD_02243', 'HMEHPJPD_02244', 'HMEHPJPD_02245', 'HMEHPJPD_02246'], 'ERR1036028(tet(45))S_76.0': ['LDJMFEKO_02617', 'ERR1036028(tet(45))S_76.0', 'LDJMFEKO_02619'], 'ERR1036037(tet(45))S_76.35': ['ERR1036037(tet(45))S_76.35', 'PMEGHOAC_02806'], 'ERR1036057(tet(45))S_76.35': ['ERR1036057(tet(45))S_76.35', 'PIIFEAGC_02618'], 'ERR1036059(tet(45))S_76.22': ['CFHKLEKO_02700', 'ERR1036059(tet(45))S_76.22', 'CFHKLEKO_02702'], 'ERR1036060(tet(45))S_76.22': ['LEOFNOFP_02657', 'ERR1036060(tet(45))S_76.22', 'LEOFNOFP_02659'], 'ERR1036070
.88', 'JCAJDADE_01973', 'JCAJDADE_01974'], 'ERR1100601(tet(45))S_76.35': ['CODHHFJH_02340', 'CODHHFJH_02341', 'CODHHFJH_02342', 'CODHHFJH_02343', 'ERR1100601(tet(45))S_76.35', 'CODHHFJH_02345', 'CODHHFJH_02346', 'CODHHFJH_02347', 'CODHHFJH_02348', 'CODHHFJH_02349', 'CODHHFJH_02350', 'CODHHFJH_02351', 'CODHHFJH_02352', 'CODHHFJH_02353', 'CODHHFJH_02354' ...
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []
# Empty DataFrame
# Columns: [query_id, sub_id, PI, bitscore, normalized_bitscore]
# Index: []

# %%
single_similarity_array_dict={}
for k,l in tqdm(Drug_singleinstance_range_10_locus_dict10.items()):
    similarity_array=[]
    for genome1 in tqdm(Single_instance_drugclass_genomedict[k].keys()):  
        u=Single_instance_drugclass_genomedict[k][genome1]
        for genome2,b in l.items():
            temp=[]
            sum1=0
            sum2=0
            u.reset_index(drop=True, inplace=True)
            
            for index in range (len(u)):
                if u["sub_id"][index] in b:
                    temp.append((u["query_id"][index],u["sub_id"][index],u["normalized_bitscore"][index]))
                
            tempframe=remove_duplicates(temp)
            sum1=round(tempframe["bitscore"].sum(),3)
            
            if Single_contig_end_flag_dict[k][genome1] ==1:
                length_original_neighborhood=len(Drug_singleinstance_range_10_locus_dict10[k][genome1])
                difference=length_original_neighborhood-len(tempframe)
                sum2= sum1+(21-difference-len(tempframe))
                
            elif Single_contig_end_flag_dict[k][genome2]==1:
                length_original_neighborhood=len(Drug_singleinstance_range_10_locus_dict10[k][genome2])
                difference=length_original_neighborhood-len(tempframe)                                 
                
                sum2= sum1+(21-difference-len(tempframe))
            else:
                sum2=sum1
                #time.sleep(0.1)
           
            similarity_array.append((genome1,genome2,round(sum2,3)))
            time.sleep(0.1)
    
    single_similarity_array_dict[k]=similarity_array
# Out:
#   0%|                                                     | 0/1 [00:00<?, ?it/s]
#   0%|                                                   | 0/455 [00:00<?, ?it/s]
#   0%|                                         | 1/455 [00:46<5:49:32, 46.20s/it]
#   0%|▏                                        | 2/455 [01:32<5:48:45, 46.19s/it]
#   1%|▎                                        | 3/455 [02:18<5:47:58, 46.19s/it]
#   1%|▎                                        | 4/455 [03:04<5:47:11, 46.19s/it]
#   1%|▍                                        | 5/455 [03:50<5:46:30, 46.20s/it]
#   1%|▌                                        | 6/455 [04:37<5:45:44, 46.20s/it]
#   2%|▋                                        | 7/455 [05:23<5:44:55, 46.20s/it]
#   2%|▋                                        | 8/455 [06:09<5:44:06, 46.19s/it]
#   2%|▊                                        | 9/455 [06:55<5:43:17, 46.18s/it]
#   2%|▉                                       | 10/455 [07:41<5:42:32, 46.19s/it]
#   2%|▉                                       | 11/455 [08:28<5:41:43, 46.18s/it]
#   3%|█                                       | 12/455 [09:14<5:40:58, 46.18s/it]
#   3%|█▏                                      | 13/455 [10:00<5:40:11, 46.18s/it]
#   3%|█▏                                      | 14/455 [10:46<5:39:22, 46.17s/it]
#   3%|█▎                                      | 15/455 [11:32<5:38:35, 46.17s/it]
#   4%|█▍                                      | 16/455 [12:18<5:37:50, 46.17s/it]
#  78%|████████████████████████████▉        | 356/455 [4:34:17<1:16:24, 46.31s/it]
#  78%|█████████████████████████████        | 357/455 [4:35:04<1:15:38, 46.31s/it]
#  79%|█████████████████████████████        | 358/455 [4:35:50<1:14:49, 46.28s/it]
#  79%|█████████████████████████████▏       | 359/455 [4:36:36<1:14:01, 46.27s/it]
#  79%|█████████████████████████████▎       | 360/455 [4:37:22<1:13:14, 46.25s/it]
#  79%|█████████████████████████████▎       | 361/455 [4:38:09<1:12:30, 46.28s/it]
#  80%|█████████████████████████████▍       | 362/455 [4:38:55<1:11:46, 46.31s/it]
#  80%|█████████████████████████████▌       | 363/455 [4:39:42<1:11:01, 46.32s/it]
#  80%|█████████████████████████████▌       | 364/455 [4:40:28<1:10:13, 46.30s/it]
#  80%|█████████████████████████████▋       | 365/455 [4:41:14<1:09:24, 46.28s/it]
#  80%|█████████████████████████████▊       | 366/455 [4:42:00<1:08:37, 46.27s/it]
#  81%|█████████████████████████████▊       | 367/455 [4:42:47<1:07:52, 46.27s/it]
#  81%|█████████████████████████████▉       | 368/455 [4:43:33<1:07:06, 46.28s/it]
#  81%|██████████████████████████████       | 369/455 [4:44:19<1:06:19, 46.27s/it]

# %%
# A function to convert the similarity matrix to symmteric matric matrix by taking the average of scores
def converttosymmetrix(j):
    newj=[]
    
    for index1 in range(len(j)):
        
        score1=j[index1][2]
        for index2 in range(len(j)):
            if j[index2][1]==j[index1][0] and j[index2][0]==j[index1][1]:
                avg=round((j[index1][2]+j[index2][2])/2,3)
        newj.append((j[index1][0],j[index1][1],avg))
    return newj

# %%
# Use the function to convert to symmetric matrix and store the final matrix in separate dictionaries
Single_instance_matrixframe={}
for i,j in tqdm(single_similarity_array_dict.items()):
    new=converttosymmetrix(j)
    finalresult=pd.DataFrame(new,columns=["Query_id","Sub_id","normalized_bitscore"])
    sim_mat=pd.crosstab(index=finalresult.iloc[:,0], columns=finalresult.iloc[:,1],values=finalresult.iloc[:,2], aggfunc=lambda x: x,colnames=None)
    Y=sim_mat.values
    Single_instance_matrixframe[i]=sim_mat
    time.sleep(0.1)

# %%
# Generate a distance matrix and generate UPGMA clusters 
#os.mkdir("Outputs/UPGMA_single_clusters")
save_path="Outputs/UPGMA_single_clusters"
dataarray=[]

# %%
hierarchy.set_link_color_palette(['r', 'g', 'y', 'm'])
matplotlib.rcParams['lines.linewidth'] = 1
for i,j in Single_instance_matrixframe.items(): 
    if len(j)>1:

        df = pd.DataFrame(j,columns=j.keys())
        r  = df.values
        df = df.transform(lambda x: 1 - x/r.max() )
        df = df.round(decimals=3)
        Y = df.values
        np.fill_diagonal(Y, 0)
        Y = distance.squareform(Y)
        fig = plt.figure(figsize=(30,5))
        Z = hierarchy.linkage(Y, 'average')
        R=dendrogram(Z, leaf_rotation=90, leaf_font_size=8, labels=j.keys())
        savename=os.path.join(save_path,i+"_.png")
        plt.ylabel("Distance between neighborhoods")
        plt.xlabel("Neighborhoods with their respective Genome IDs")
        plt.savefig(savename,bbox_inches='tight', dpi=100)
        plt.close()
